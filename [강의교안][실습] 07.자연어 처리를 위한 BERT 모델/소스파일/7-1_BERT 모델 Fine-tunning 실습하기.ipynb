# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.15.0-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 5.1 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 14.0 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 13.1 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 6.1 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 356 kB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.2.1 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.15.0

# %%
from transformers import BertForSequenceClassification

bert_model_name = 'bert-base-uncased'

model = BertForSequenceClassification.from_pretrained(bert_model_name)
# Out:
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/420M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
for name, param in model.bert.named_parameters():
  print(name)
# Out:
# embeddings.word_embeddings.weight
# embeddings.position_embeddings.weight
# embeddings.token_type_embeddings.weight
# embeddings.LayerNorm.weight
# embeddings.LayerNorm.bias
# encoder.layer.0.attention.self.query.weight
# encoder.layer.0.attention.self.query.bias
# encoder.layer.0.attention.self.key.weight
# encoder.layer.0.attention.self.key.bias
# encoder.layer.0.attention.self.value.weight
# encoder.layer.0.attention.self.value.bias
# encoder.layer.0.attention.output.dense.weight
# encoder.layer.0.attention.output.dense.bias
# encoder.layer.0.attention.output.LayerNorm.weight
# encoder.layer.0.attention.output.LayerNorm.bias
# encoder.layer.0.intermediate.dense.weight
# encoder.layer.0.intermediate.dense.bias
# encoder.layer.0.output.dense.weight
# encoder.layer.0.output.dense.bias
# encoder.layer.0.output.LayerNorm.weight
# encoder.layer.0.output.LayerNorm.bias
# encoder.layer.1.attention.self.query.weight
# encoder.layer.1.attention.self.query.bias
# encoder.layer.1.attention.self.key.weight
# encoder.layer.1.attention.self.key.bias
# encoder.layer.1.attention.self.value.weight
# encoder.layer.1.attention.self.value.bias
# encoder.layer.1.attention.output.dense.weight
# encoder.layer.1.attention.output.dense.bias
# encoder.layer.1.attention.output.LayerNorm.weight
# encoder.layer.1.attention.output.LayerNorm.bias
# encoder.layer.1.intermediate.dense.weight
# encoder.layer.1.intermediate.dense.bias
# encoder.layer.1.output.dense.weight
# encoder.layer.1.output.dense.bias
# encoder.layer.1.output.LayerNorm.weight
# encoder.layer.1.output.LayerNorm.bias
# encoder.layer.2.attention.self.query.weight
# encoder.layer.2.attention.self.query.bias
# encoder.layer.2.attention.self.key.weight
# encoder.layer.2.attention.self.key.bias
# encoder.layer.2.attention.self.value.weight
# encoder.layer.2.attention.self.value.bias
# encoder.layer.2.attention.output.dense.weight
# encoder.layer.2.attention.output.dense.bias
# encoder.layer.2.attention.output.LayerNorm.weight
# encoder.layer.2.attention.output.LayerNorm.bias
# encoder.layer.2.intermediate.dense.weight
# encoder.layer.2.intermediate.dense.bias
# encoder.layer.2.output.dense.weight
# encoder.layer.2.output.dense.bias
# encoder.layer.2.output.LayerNorm.weight
# encoder.layer.2.output.LayerNorm.bias
# encoder.layer.3.attention.self.query.weight
# encoder.layer.3.attention.self.query.bias
# encoder.layer.3.attention.self.key.weight
# encoder.layer.3.attention.self.key.bias
# encoder.layer.3.attention.self.value.weight
# encoder.layer.3.attention.self.value.bias
# encoder.layer.3.attention.output.dense.weight
# encoder.layer.3.attention.output.dense.bias
# encoder.layer.3.attention.output.LayerNorm.weight
# encoder.layer.3.attention.output.LayerNorm.bias
# encoder.layer.3.intermediate.dense.weight
# encoder.layer.3.intermediate.dense.bias
# encoder.layer.3.output.dense.weight
# encoder.layer.3.output.dense.bias
# encoder.layer.3.output.LayerNorm.weight
# encoder.layer.3.output.LayerNorm.bias
# encoder.layer.4.attention.self.query.weight
# encoder.layer.4.attention.self.query.bias
# encoder.layer.4.attention.self.key.weight
# encoder.layer.4.attention.self.key.bias
# encoder.layer.4.attention.self.value.weight
# encoder.layer.4.attention.self.value.bias
# encoder.layer.4.attention.output.dense.weight
# encoder.layer.4.attention.output.dense.bias
# encoder.layer.4.attention.output.LayerNorm.weight
# encoder.layer.4.attention.output.LayerNorm.bias
# encoder.layer.4.intermediate.dense.weight
# encoder.layer.4.intermediate.dense.bias
# encoder.layer.4.output.dense.weight
# encoder.layer.4.output.dense.bias
# encoder.layer.4.output.LayerNorm.weight
# encoder.layer.4.output.LayerNorm.bias
# encoder.layer.5.attention.self.query.weight
# encoder.layer.5.attention.self.query.bias
# encoder.layer.5.attention.self.key.weight
# encoder.layer.5.attention.self.key.bias
# encoder.layer.5.attention.self.value.weight
# encoder.layer.5.attention.self.value.bias
# encoder.layer.5.attention.output.dense.weight
# encoder.layer.5.attention.output.dense.bias
# encoder.layer.5.attention.output.LayerNorm.weight
# encoder.layer.5.attention.output.LayerNorm.bias
# encoder.layer.5.intermediate.dense.weight
# encoder.layer.5.intermediate.dense.bias
# encoder.layer.5.output.dense.weight
# encoder.layer.5.output.dense.bias
# encoder.layer.5.output.LayerNorm.weight
# encoder.layer.5.output.LayerNorm.bias
# encoder.layer.6.attention.self.query.weight
# encoder.layer.6.attention.self.query.bias
# encoder.layer.6.attention.self.key.weight
# encoder.layer.6.attention.self.key.bias
# encoder.layer.6.attention.self.value.weight
# encoder.layer.6.attention.self.value.bias
# encoder.layer.6.attention.output.dense.weight
# encoder.layer.6.attention.output.dense.bias
# encoder.layer.6.attention.output.LayerNorm.weight
# encoder.layer.6.attention.output.LayerNorm.bias
# encoder.layer.6.intermediate.dense.weight
# encoder.layer.6.intermediate.dense.bias
# encoder.layer.6.output.dense.weight
# encoder.layer.6.output.dense.bias
# encoder.layer.6.output.LayerNorm.weight
# encoder.layer.6.output.LayerNorm.bias
# encoder.layer.7.attention.self.query.weight
# encoder.layer.7.attention.self.query.bias
# encoder.layer.7.attention.self.key.weight
# encoder.layer.7.attention.self.key.bias
# encoder.layer.7.attention.self.value.weight
# encoder.layer.7.attention.self.value.bias
# encoder.layer.7.attention.output.dense.weight
# encoder.layer.7.attention.output.dense.bias
# encoder.layer.7.attention.output.LayerNorm.weight
# encoder.layer.7.attention.output.LayerNorm.bias
# encoder.layer.7.intermediate.dense.weight
# encoder.layer.7.intermediate.dense.bias
# encoder.layer.7.output.dense.weight
# encoder.layer.7.output.dense.bias
# encoder.layer.7.output.LayerNorm.weight
# encoder.layer.7.output.LayerNorm.bias
# encoder.layer.8.attention.self.query.weight
# encoder.layer.8.attention.self.query.bias
# encoder.layer.8.attention.self.key.weight
# encoder.layer.8.attention.self.key.bias
# encoder.layer.8.attention.self.value.weight
# encoder.layer.8.attention.self.value.bias
# encoder.layer.8.attention.output.dense.weight
# encoder.layer.8.attention.output.dense.bias
# encoder.layer.8.attention.output.LayerNorm.weight
# encoder.layer.8.attention.output.LayerNorm.bias
# encoder.layer.8.intermediate.dense.weight
# encoder.layer.8.intermediate.dense.bias
# encoder.layer.8.output.dense.weight
# encoder.layer.8.output.dense.bias
# encoder.layer.8.output.LayerNorm.weight
# encoder.layer.8.output.LayerNorm.bias
# encoder.layer.9.attention.self.query.weight
# encoder.layer.9.attention.self.query.bias
# encoder.layer.9.attention.self.key.weight
# encoder.layer.9.attention.self.key.bias
# encoder.layer.9.attention.self.value.weight
# encoder.layer.9.attention.self.value.bias
# encoder.layer.9.attention.output.dense.weight
# encoder.layer.9.attention.output.dense.bias
# encoder.layer.9.attention.output.LayerNorm.weight
# encoder.layer.9.attention.output.LayerNorm.bias
# encoder.layer.9.intermediate.dense.weight
# encoder.layer.9.intermediate.dense.bias
# encoder.layer.9.output.dense.weight
# encoder.layer.9.output.dense.bias
# encoder.layer.9.output.LayerNorm.weight
# encoder.layer.9.output.LayerNorm.bias
# encoder.layer.10.attention.self.query.weight
# encoder.layer.10.attention.self.query.bias
# encoder.layer.10.attention.self.key.weight
# encoder.layer.10.attention.self.key.bias
# encoder.layer.10.attention.self.value.weight
# encoder.layer.10.attention.self.value.bias
# encoder.layer.10.attention.output.dense.weight
# encoder.layer.10.attention.output.dense.bias
# encoder.layer.10.attention.output.LayerNorm.weight
# encoder.layer.10.attention.output.LayerNorm.bias
# encoder.layer.10.intermediate.dense.weight
# encoder.layer.10.intermediate.dense.bias
# encoder.layer.10.output.dense.weight
# encoder.layer.10.output.dense.bias
# encoder.layer.10.output.LayerNorm.weight
# encoder.layer.10.output.LayerNorm.bias
# encoder.layer.11.attention.self.query.weight
# encoder.layer.11.attention.self.query.bias
# encoder.layer.11.attention.self.key.weight
# encoder.layer.11.attention.self.key.bias
# encoder.layer.11.attention.self.value.weight
# encoder.layer.11.attention.self.value.bias
# encoder.layer.11.attention.output.dense.weight
# encoder.layer.11.attention.output.dense.bias
# encoder.layer.11.attention.output.LayerNorm.weight
# encoder.layer.11.attention.output.LayerNorm.bias
# encoder.layer.11.intermediate.dense.weight
# encoder.layer.11.intermediate.dense.bias
# encoder.layer.11.output.dense.weight
# encoder.layer.11.output.dense.bias
# encoder.layer.11.output.LayerNorm.weight
# encoder.layer.11.output.LayerNorm.bias
# pooler.dense.weight
# pooler.dense.bias

# %%
bert_model_name = 'bert-large-uncased'
model = BertForSequenceClassification.from_pretrained(bert_model_name)
# Out:
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.25G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-large-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
for name, param in model.bert.named_parameters():
  print(name, param)
# Out:
# embeddings.word_embeddings.weight Parameter containing:
# tensor([[-0.0419,  0.0022, -0.0314,  ..., -0.0146, -0.0358, -0.0929],
#         [-0.0434, -0.0115, -0.0065,  ..., -0.0273, -0.0310, -0.1084],
#         [-0.0622, -0.0114, -0.0073,  ..., -0.0247, -0.0334, -0.0915],
#         ...,
#         [ 0.0239, -0.0083, -0.0061,  ...,  0.0176,  0.0214, -0.0763],
#         [-0.0468, -0.0018,  0.0020,  ..., -0.0173, -0.0243, -0.1124],
#         [-0.0185, -0.0369, -0.0623,  ..., -0.0054, -0.0412, -0.0847]],
#        requires_grad=True)
# embeddings.position_embeddings.weight Parameter containing:
# tensor([[ 0.0041, -0.0139, -0.0263,  ..., -0.0042, -0.0212,  0.0148],
#         [ 0.0097,  0.0067, -0.0287,  ...,  0.0003,  0.0051,  0.0049],
#         [ 0.0005, -0.0129, -0.0019,  ..., -0.0006,  0.0247,  0.0181],
#         ...,
#         [ 0.0047,  0.0026,  0.0021,  ...,  0.0092, -0.0113,  0.0185],
#         [-0.0161, -0.0068,  0.0181,  ...,  0.0040, -0.0194,  0.0058],
#         [ 0.0218,  0.0243,  0.0312,  ...,  0.0091,  0.0013,  0.0184]],
#        requires_grad=True)
# embeddings.token_type_embeddings.weight Parameter containing:
# tensor([[-0.0027, -0.0044,  0.0125,  ..., -0.0058,  0.0047, -0.0005],
#         [ 0.0047, -0.0022, -0.0008,  ..., -0.0091, -0.0024,  0.0115]],
#        requires_grad=True)
# embeddings.LayerNorm.weight Parameter containing:
# tensor([0.8801, 0.8972, 0.8730,  ..., 0.9364, 0.9117, 0.8275],
#        requires_grad=True)
# embeddings.LayerNorm.bias Parameter containing:
# tensor([-0.0303, -0.0041, -0.0374,  ...,  0.0183, -0.0110,  0.0441],
#        requires_grad=True)
# encoder.layer.0.attention.self.query.weight Parameter containing:
# tensor([[ 0.0167, -0.0422, -0.0425,  ...,  0.0302, -0.0341,  0.0251],
#         [ 0.0323,  0.0347, -0.0041,  ..., -0.0722,  0.0031, -0.0351],
#         [ 0.0387, -0.0293, -0.0694,  ...,  0.0492,  0.0201, -0.0727],
#         ...,
#         [ 0.0035,  0.0081, -0.0337,  ...,  0.0460,  0.0268,  0.0747],
#         [ 0.0513,  0.0131,  0.0735,  ..., -0.0127,  0.0144, -0.0400],
#         [ 0.0385,  0.0013, -0.0272,  ...,  0.0148,  0.0399,  0.0339]],
#        requires_grad=True)
# encoder.layer.0.attention.self.query.bias Parameter containing:
# tensor([ 0.0087,  0.1857, -0.0485,  ..., -0.2867, -0.1432,  0.1627],
#        requires_grad=True)
# encoder.layer.0.attention.self.key.weight Parameter containing:
# tensor([[-0.0571,  0.0281, -0.0172,  ..., -0.0023,  0.0284,  0.0498],
#         [-0.0449,  0.0399, -0.0205,  ..., -0.0576,  0.0355,  0.0228],
#         [ 0.0182,  0.0311,  0.0593,  ...,  0.0873,  0.0816, -0.0162],
#         ...,
#         [-0.0109,  0.0104, -0.0188,  ..., -0.0390,  0.0144,  0.0371],
#         [-0.0016,  0.0229,  0.0056,  ...,  0.0203, -0.0179,  0.0431],
#         [ 0.0034, -0.0112, -0.0204,  ...,  0.0052,  0.0094, -0.0235]],
#        requires_grad=True)
# encoder.layer.0.attention.self.key.bias Parameter containing:
# tensor([-0.0031,  0.0022,  0.0020,  ...,  0.0007, -0.0002,  0.0002],
#        requires_grad=True)
# encoder.layer.0.attention.self.value.weight Parameter containing:
# tensor([[-0.0043, -0.0113,  0.0281,  ...,  0.0033, -0.0223,  0.0054],
#         [-0.0352, -0.0200, -0.0177,  ...,  0.0310,  0.0244,  0.0285],
#         [-0.0037, -0.0024, -0.0635,  ..., -0.0428,  0.0309,  0.0052],
#         ...,
#         [ 0.0302, -0.0310,  0.0043,  ...,  0.0175,  0.0145, -0.0235],
#         [-0.0345, -0.0232, -0.0001,  ..., -0.0307, -0.0095,  0.0285],
#         [-0.0143, -0.0174, -0.0008,  ...,  0.0094,  0.0043, -0.0017]],
#        requires_grad=True)
# encoder.layer.0.attention.self.value.bias Parameter containing:
# tensor([-0.0010,  0.0183, -0.0122,  ..., -0.0048,  0.0014, -0.0202],
#        requires_grad=True)
# encoder.layer.0.attention.output.dense.weight Parameter containing:
# tensor([[ 0.0012,  0.0084, -0.0162,  ...,  0.0123, -0.0039, -0.0098],
#         [ 0.0059, -0.0185,  0.0313,  ..., -0.0329, -0.0133, -0.0247],
#         [ 0.0168, -0.0150, -0.0164,  ...,  0.0332,  0.0079, -0.0137],
#         ...,
#         [-0.0527, -0.0152, -0.0410,  ...,  0.0290, -0.0049, -0.0136],
#         [-0.0076,  0.0398,  0.0136,  ..., -0.0018,  0.0228,  0.0154],
#         [-0.0385,  0.0236,  0.0116,  ..., -0.0212, -0.0008, -0.0085]],
#        requires_grad=True)
# encoder.layer.0.attention.output.dense.bias Parameter containing:
# tensor([-0.0259,  0.0296,  0.0099,  ..., -0.0157,  0.0172,  0.0048],
#        requires_grad=True)
# encoder.layer.0.attention.output.LayerNorm.weight Parameter containing:
# tensor([1.0223, 1.0159, 1.0278,  ..., 1.0545, 1.0441, 1.0321],
#        requires_grad=True)
# encoder.layer.0.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0568,  0.0686,  0.2091,  ..., -0.3218,  0.2872, -0.0747],
#        requires_grad=True)
# encoder.layer.0.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0573, -0.0164,  0.0500,  ...,  0.0499,  0.0380,  0.0136],
#         [ 0.0254,  0.0115,  0.0222,  ...,  0.0491, -0.0255,  0.0345],
#         [-0.0262,  0.0537,  0.0151,  ...,  0.0100, -0.0887, -0.0037],
#         ...,
#         [ 0.0100,  0.0010, -0.0044,  ...,  0.0413, -0.0270, -0.0023],
#         [ 0.0341,  0.0658, -0.0308,  ...,  0.0110,  0.0557,  0.0961],
#         [-0.0437,  0.0143,  0.0067,  ...,  0.0104, -0.0125, -0.0128]],
#        requires_grad=True)
# encoder.layer.0.intermediate.dense.bias Parameter containing:
# tensor([-0.1383, -0.0872, -0.0970,  ..., -0.0788, -0.0744, -0.0539],
#        requires_grad=True)
# encoder.layer.0.output.dense.weight Parameter containing:
# tensor([[ 0.0366,  0.0135,  0.0492,  ..., -0.0274,  0.0493,  0.0242],
#         [-0.0113,  0.0504,  0.0469,  ..., -0.0269, -0.0224, -0.0305],
#         [ 0.0192, -0.0152,  0.0119,  ...,  0.0115, -0.0182, -0.0063],
#         ...,
#         [-0.0370, -0.0460,  0.0203,  ...,  0.0157, -0.0529,  0.0139],
#         [-0.0523, -0.0192, -0.0612,  ..., -0.0515,  0.0169,  0.0098],
#         [ 0.0277, -0.0029, -0.0349,  ...,  0.0014, -0.0453,  0.0052]],
#        requires_grad=True)
# encoder.layer.0.output.dense.bias Parameter containing:
# tensor([ 0.0196,  0.0067, -0.0165,  ...,  0.0177, -0.0003,  0.0366],
#        requires_grad=True)
# encoder.layer.0.output.LayerNorm.weight Parameter containing:
# tensor([0.9134, 0.9069, 0.8905,  ..., 0.8861, 0.9277, 0.8856],
#        requires_grad=True)
# encoder.layer.0.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0189,  0.0241, -0.0265,  ...,  0.1248, -0.0310,  0.0613],
#        requires_grad=True)
# encoder.layer.1.attention.self.query.weight Parameter containing:
# tensor([[ 0.0377,  0.0077, -0.0352,  ..., -0.0110,  0.0054, -0.0216],
#         [ 0.0313, -0.0175,  0.0093,  ...,  0.0098, -0.0212,  0.0027],
#         [-0.0543,  0.0006,  0.0116,  ...,  0.0155, -0.0327,  0.0438],
#         ...,
#         [ 0.0019,  0.0546,  0.0053,  ...,  0.0192, -0.0125, -0.0138],
#         [-0.0074,  0.0109, -0.0073,  ...,  0.0143,  0.0169, -0.0136],
#         [-0.0171, -0.0679, -0.0456,  ..., -0.0463,  0.0099, -0.0421]],
#        requires_grad=True)
# encoder.layer.1.attention.self.query.bias Parameter containing:
# tensor([-0.0349, -0.0187,  0.0331,  ..., -0.0264,  0.0608, -0.0007],
#        requires_grad=True)
# encoder.layer.1.attention.self.key.weight Parameter containing:
# tensor([[-0.0039,  0.0144,  0.0084,  ..., -0.0016,  0.0073,  0.0269],
#         [-0.0529,  0.0067, -0.0182,  ..., -0.0240, -0.0141, -0.0149],
#         [-0.0241, -0.0103,  0.0622,  ..., -0.0216,  0.0089,  0.0323],
#         ...,
#         [-0.0240, -0.0493,  0.0061,  ...,  0.0075,  0.0239,  0.0659],
#         [ 0.0535,  0.0297,  0.0233,  ..., -0.0207,  0.0406, -0.0255],
#         [-0.0287,  0.0166, -0.0174,  ...,  0.0297, -0.0216,  0.0351]],
#        requires_grad=True)
# encoder.layer.1.attention.self.key.bias Parameter containing:
# tensor([-0.0030, -0.0010,  0.0053,  ..., -0.0023, -0.0006,  0.0007],
#        requires_grad=True)
# encoder.layer.1.attention.self.value.weight Parameter containing:
# tensor([[-0.0182,  0.0008,  0.0225,  ...,  0.0276, -0.0075,  0.0740],
#         [ 0.0285, -0.0466, -0.0197,  ..., -0.0116, -0.0393, -0.0102],
#         [-0.0044,  0.0135,  0.0176,  ...,  0.0315,  0.0351,  0.0167],
#         ...,
#         [-0.0014, -0.0125, -0.0001,  ..., -0.0031, -0.0457,  0.0144],
#         [-0.0393, -0.0026, -0.0124,  ..., -0.0123, -0.0186, -0.0095],
#         [ 0.0033,  0.0217,  0.0066,  ..., -0.0225,  0.0186, -0.0115]],
#        requires_grad=True)
# encoder.layer.1.attention.self.value.bias Parameter containing:
# tensor([-0.0038, -0.0166, -0.0119,  ..., -0.0076, -0.0018,  0.0045],
#        requires_grad=True)
# encoder.layer.1.attention.output.dense.weight Parameter containing:
# tensor([[-0.0167, -0.0028,  0.0273,  ...,  0.0291,  0.0377, -0.0008],
#         [ 0.0046, -0.0383, -0.0025,  ..., -0.0069, -0.0010, -0.0107],
#         [ 0.0418,  0.0105,  0.0085,  ..., -0.0111,  0.0034, -0.0246],
#         ...,
#         [ 0.0021,  0.0049, -0.0293,  ...,  0.0178,  0.0187,  0.0154],
#         [-0.0111,  0.0084,  0.0020,  ...,  0.0466,  0.0003, -0.0162],
#         [ 0.0303,  0.0377,  0.0008,  ..., -0.0098,  0.0070,  0.0303]],
#        requires_grad=True)
# encoder.layer.1.attention.output.dense.bias Parameter containing:
# tensor([ 0.0091,  0.0031, -0.0063,  ..., -0.0180,  0.0236,  0.0213],
#        requires_grad=True)
# encoder.layer.1.attention.output.LayerNorm.weight Parameter containing:
# tensor([1.0149, 0.9907, 1.0102,  ..., 1.0224, 1.0286, 1.0217],
#        requires_grad=True)
# encoder.layer.1.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0973,  0.1046,  0.0980,  ..., -0.1860,  0.1964, -0.0124],
#        requires_grad=True)
# encoder.layer.1.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0242,  0.0313,  0.0073,  ...,  0.0282, -0.0085, -0.0142],
#         [ 0.0252,  0.0128, -0.0882,  ...,  0.0530, -0.0882, -0.0490],
#         [-0.0728, -0.0252, -0.0248,  ...,  0.0063, -0.0259, -0.0317],
#         ...,
#         [ 0.0684, -0.0231, -0.0270,  ..., -0.0062, -0.0221, -0.0348],
#         [-0.0132, -0.0320,  0.0564,  ..., -0.0240, -0.0383, -0.0201],
#         [ 0.0258, -0.0265, -0.0393,  ..., -0.0712, -0.0152, -0.0365]],
#        requires_grad=True)
# encoder.layer.1.intermediate.dense.bias Parameter containing:
# tensor([-0.0646, -0.0781, -0.0466,  ..., -0.0526, -0.0698, -0.0622],
#        requires_grad=True)
# encoder.layer.1.output.dense.weight Parameter containing:
# tensor([[-0.0043,  0.0077, -0.0470,  ...,  0.0370, -0.0171,  0.0405],
#         [-0.0021, -0.0078,  0.0070,  ..., -0.0386,  0.0198,  0.0137],
#         [-0.0244, -0.0163, -0.0239,  ...,  0.0011,  0.0027,  0.0912],
#         ...,
#         [ 0.0524,  0.0020, -0.0486,  ...,  0.0069, -0.0152, -0.0111],
#         [ 0.0316, -0.0059,  0.0128,  ..., -0.0126,  0.0073,  0.0388],
#         [-0.0085,  0.0165, -0.0253,  ...,  0.0124,  0.0319,  0.0150]],
#        requires_grad=True)
# encoder.layer.1.output.dense.bias Parameter containing:
# tensor([-0.0074,  0.0161, -0.0435,  ...,  0.0413, -0.0100,  0.0013],
#        requires_grad=True)
# encoder.layer.1.output.LayerNorm.weight Parameter containing:
# tensor([0.9435, 0.9484, 0.9432,  ..., 0.9351, 0.9598, 0.9404],
#        requires_grad=True)
# encoder.layer.1.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0792, -0.0241,  0.0017,  ...,  0.1076, -0.0704,  0.0217],
#        requires_grad=True)
# encoder.layer.2.attention.self.query.weight Parameter containing:
# tensor([[ 0.0080, -0.0390, -0.0392,  ...,  0.0480,  0.0586,  0.0723],
#         [ 0.0424,  0.0570,  0.0172,  ...,  0.0436,  0.0100, -0.0178],
#         [-0.0874, -0.0358,  0.0498,  ...,  0.0166,  0.0108, -0.0458],
#         ...,
#         [ 0.0121, -0.0075,  0.0065,  ...,  0.0683,  0.0129, -0.1068],
#         [ 0.0051, -0.0203, -0.0063,  ..., -0.0145, -0.0548, -0.0127],
#         [ 0.0368,  0.0310, -0.0037,  ..., -0.0352, -0.0483,  0.0392]],
#        requires_grad=True)
# encoder.layer.2.attention.self.query.bias Parameter containing:
# tensor([ 0.0005,  0.0655, -0.0002,  ..., -0.0587, -0.0060, -0.0238],
#        requires_grad=True)
# encoder.layer.2.attention.self.key.weight Parameter containing:
# tensor([[-0.0436,  0.0257, -0.0348,  ..., -0.0176, -0.0151, -0.0086],
#         [-0.0490, -0.0144,  0.0353,  ..., -0.0330, -0.0081, -0.0097],
#         [ 0.0142,  0.0350, -0.0127,  ...,  0.0318, -0.0912, -0.0357],
#         ...,
#         [ 0.0034,  0.0612, -0.0198,  ...,  0.0099, -0.0266,  0.0329],
#         [ 0.0466,  0.0258,  0.0004,  ...,  0.0222, -0.0057,  0.0086],
#         [-0.0145, -0.0014,  0.0027,  ...,  0.0439, -0.0421,  0.0754]],
#        requires_grad=True)
# encoder.layer.2.attention.self.key.bias Parameter containing:
# tensor([-0.0030,  0.0004, -0.0094,  ..., -0.0003, -0.0009, -0.0001],
#        requires_grad=True)
# encoder.layer.2.attention.self.value.weight Parameter containing:
# tensor([[-0.0335,  0.0321, -0.0119,  ..., -0.0014, -0.0063, -0.0563],
#         [-0.0209,  0.0132, -0.0466,  ..., -0.0033,  0.0105,  0.0029],
#         [-0.0088, -0.0170, -0.0282,  ..., -0.0400, -0.0137, -0.0091],
#         ...,
#         [-0.0050,  0.0255, -0.0111,  ...,  0.0432,  0.0253, -0.0074],
#         [-0.0065, -0.0415,  0.0081,  ...,  0.0129, -0.0275, -0.0357],
#         [-0.0152,  0.0019,  0.0302,  ..., -0.0293,  0.0243,  0.0010]],
#        requires_grad=True)
# encoder.layer.2.attention.self.value.bias Parameter containing:
# tensor([ 0.0054, -0.0777, -0.0119,  ...,  0.0221,  0.0032,  0.0010],
#        requires_grad=True)
# encoder.layer.2.attention.output.dense.weight Parameter containing:
# tensor([[-0.0600,  0.0451, -0.0082,  ...,  0.0118, -0.0080,  0.0354],
#         [-0.0193, -0.0188,  0.0099,  ..., -0.0161,  0.0012, -0.0056],
#         [-0.0131,  0.0420, -0.0509,  ...,  0.0403, -0.0002,  0.0091],
#         ...,
#         [-0.0296, -0.0072, -0.0017,  ..., -0.0252,  0.0039, -0.0147],
#         [ 0.0296,  0.0229, -0.0021,  ..., -0.0425,  0.0095, -0.0127],
#         [-0.0201, -0.0074, -0.0427,  ..., -0.0115,  0.0266,  0.0105]],
#        requires_grad=True)
# encoder.layer.2.attention.output.dense.bias Parameter containing:
# tensor([ 0.0193, -0.0342,  0.0175,  ..., -0.0143, -0.0067,  0.0397],
#        requires_grad=True)
# encoder.layer.2.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.9922, 0.9859, 1.0080,  ..., 1.0007, 0.9944, 0.9829],
#        requires_grad=True)
# encoder.layer.2.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0745,  0.0468,  0.1724,  ..., -0.1062,  0.1043, -0.0145],
#        requires_grad=True)
# encoder.layer.2.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0135,  0.0602, -0.0610,  ...,  0.0111, -0.0125,  0.0404],
#         [-0.0012, -0.0622, -0.0593,  ..., -0.0352, -0.0347,  0.0217],
#         [ 0.0069, -0.0212, -0.0166,  ...,  0.0384,  0.0119,  0.0531],
#         ...,
#         [-0.0496,  0.0621, -0.0284,  ...,  0.0047,  0.0125,  0.0200],
#         [ 0.0214, -0.0140, -0.0038,  ..., -0.0240,  0.0365, -0.0558],
#         [-0.0536,  0.0357, -0.0020,  ..., -0.0257,  0.0614,  0.0351]],
#        requires_grad=True)
# encoder.layer.2.intermediate.dense.bias Parameter containing:
# tensor([-0.0628, -0.0646, -0.0439,  ..., -0.0353, -0.0722, -0.0549],
#        requires_grad=True)
# encoder.layer.2.output.dense.weight Parameter containing:
# tensor([[-0.0218,  0.0245,  0.0065,  ..., -0.0311,  0.0022,  0.0078],
#         [ 0.0139,  0.0062,  0.0507,  ...,  0.0215, -0.0290,  0.0189],
#         [-0.0405,  0.0629, -0.0171,  ..., -0.0286,  0.0296,  0.0316],
#         ...,
#         [ 0.0303, -0.0372,  0.0222,  ...,  0.0150, -0.0312,  0.0283],
#         [ 0.0382,  0.0227,  0.0151,  ...,  0.0508,  0.0116,  0.0244],
#         [ 0.0046, -0.0326,  0.0502,  ...,  0.0186, -0.0525,  0.0143]],
#        requires_grad=True)
# encoder.layer.2.output.dense.bias Parameter containing:
# tensor([ 0.0038,  0.0072, -0.0306,  ...,  0.0568, -0.0237,  0.0038],
#        requires_grad=True)
# encoder.layer.2.output.LayerNorm.weight Parameter containing:
# tensor([0.9300, 0.9419, 0.9198,  ..., 0.9347, 0.9537, 0.9175],
#        requires_grad=True)
# encoder.layer.2.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0681, -0.0042, -0.0613,  ...,  0.1118, -0.0474,  0.0479],
#        requires_grad=True)
# encoder.layer.3.attention.self.query.weight Parameter containing:
# tensor([[-0.0601,  0.0315, -0.0367,  ...,  0.0554,  0.0622, -0.0079],
#         [ 0.0126, -0.0642,  0.0141,  ...,  0.0257, -0.0571, -0.0080],
#         [ 0.0019,  0.0149, -0.0028,  ...,  0.0326,  0.0008,  0.0220],
#         ...,
#         [-0.0189,  0.0309,  0.0218,  ...,  0.0393, -0.0069, -0.0086],
#         [-0.0691, -0.0036,  0.0067,  ...,  0.0435,  0.0450,  0.0668],
#         [-0.0102, -0.0385,  0.0383,  ...,  0.0838,  0.0456, -0.0303]],
#        requires_grad=True)
# encoder.layer.3.attention.self.query.bias Parameter containing:
# tensor([-0.0226,  0.0160, -0.0183,  ..., -0.0556,  0.0249, -0.0446],
#        requires_grad=True)
# encoder.layer.3.attention.self.key.weight Parameter containing:
# tensor([[-0.0587, -0.0343,  0.0386,  ..., -0.0288, -0.0430, -0.0296],
#         [-0.0226,  0.0484,  0.0192,  ..., -0.0042,  0.0258,  0.0544],
#         [-0.0216, -0.0238, -0.0302,  ..., -0.0660,  0.0448,  0.0411],
#         ...,
#         [ 0.0048,  0.0376,  0.0246,  ..., -0.0517,  0.0318,  0.0036],
#         [ 0.0095,  0.0163,  0.0177,  ..., -0.0234, -0.0278, -0.0328],
#         [-0.0305, -0.0033,  0.0027,  ...,  0.0014, -0.0305, -0.0233]],
#        requires_grad=True)
# encoder.layer.3.attention.self.key.bias Parameter containing:
# tensor([ 0.0008, -0.0018, -0.0006,  ..., -0.0008, -0.0009, -0.0010],
#        requires_grad=True)
# encoder.layer.3.attention.self.value.weight Parameter containing:
# tensor([[-0.0028,  0.0181, -0.0059,  ...,  0.0766, -0.0135, -0.0571],
#         [ 0.0190, -0.0012,  0.0088,  ...,  0.0226, -0.0309, -0.0157],
#         [ 0.0069,  0.0205,  0.0202,  ...,  0.0307, -0.0725, -0.0190],
#         ...,
#         [ 0.0152, -0.0215,  0.0271,  ...,  0.0106, -0.0125, -0.0018],
#         [-0.0406, -0.0279, -0.0256,  ..., -0.0036, -0.0349,  0.0032],
#         [ 0.0163, -0.0053, -0.0167,  ..., -0.0181, -0.0171,  0.0383]],
#        requires_grad=True)
# encoder.layer.3.attention.self.value.bias Parameter containing:
# tensor([ 0.0046, -0.0146, -0.0185,  ...,  0.0163, -0.0135, -0.0162],
#        requires_grad=True)
# encoder.layer.3.attention.output.dense.weight Parameter containing:
# tensor([[ 0.0122, -0.0039,  0.0168,  ...,  0.0138,  0.0013, -0.0101],
#         [-0.0209,  0.0208, -0.0265,  ..., -0.0051,  0.0269, -0.0044],
#         [ 0.0033, -0.0194, -0.0089,  ..., -0.0003,  0.0226,  0.0015],
#         ...,
#         [-0.0207,  0.0033, -0.0212,  ...,  0.0087, -0.0025,  0.0063],
#         [-0.0275,  0.0194,  0.0329,  ..., -0.0172,  0.0335,  0.0086],
#         [ 0.0185,  0.0040,  0.0184,  ..., -0.0167,  0.0016,  0.0102]],
#        requires_grad=True)
# encoder.layer.3.attention.output.dense.bias Parameter containing:
# tensor([-0.0198,  0.0680, -0.0337,  ...,  0.0489, -0.0094,  0.0011],
#        requires_grad=True)
# encoder.layer.3.attention.output.LayerNorm.weight Parameter containing:
# tensor([1.0002, 0.9855, 1.0081,  ..., 0.9869, 0.9863, 0.9685],
#        requires_grad=True)
# encoder.layer.3.attention.output.LayerNorm.bias Parameter containing:
# tensor([-1.3775e-01,  1.1437e-04,  1.9784e-01,  ..., -5.1143e-02,
#          5.0889e-02,  1.9371e-02], requires_grad=True)
# encoder.layer.3.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0661,  0.0230, -0.0260,  ..., -0.0155, -0.0764, -0.0195],
#         [-0.0131, -0.0811, -0.0069,  ...,  0.0039,  0.0327,  0.0755],
#         [-0.0022,  0.0036, -0.0714,  ...,  0.0273, -0.0434,  0.0318],
#         ...,
#         [ 0.0615,  0.0572, -0.0159,  ..., -0.0129, -0.0265,  0.0489],
#         [ 0.0072,  0.0521, -0.0216,  ..., -0.0349,  0.0060, -0.0048],
#         [ 0.0448, -0.0491, -0.0080,  ...,  0.0471,  0.0030,  0.0265]],
#        requires_grad=True)
# encoder.layer.3.intermediate.dense.bias Parameter containing:
# tensor([-0.0705, -0.0635, -0.0625,  ..., -0.0614, -0.0653, -0.0579],
#        requires_grad=True)
# encoder.layer.3.output.dense.weight Parameter containing:
# tensor([[-0.0512, -0.0199,  0.0281,  ...,  0.0752, -0.0044,  0.0117],
#         [-0.0226,  0.0350,  0.0155,  ...,  0.0204,  0.0092,  0.0332],
#         [ 0.0272, -0.0500, -0.0301,  ..., -0.0179, -0.0368,  0.0114],
#         ...,
#         [-0.0150,  0.0069,  0.0229,  ...,  0.0099, -0.0602,  0.0269],
#         [ 0.0211,  0.0304, -0.0175,  ..., -0.0572, -0.0144, -0.0237],
#         [-0.0279, -0.0206, -0.0495,  ..., -0.0278,  0.0102, -0.0294]],
#        requires_grad=True)
# encoder.layer.3.output.dense.bias Parameter containing:
# tensor([-0.0046,  0.0263, -0.0540,  ...,  0.0728, -0.0265, -0.0161],
#        requires_grad=True)
# encoder.layer.3.output.LayerNorm.weight Parameter containing:
# tensor([0.9145, 0.9362, 0.8880,  ..., 0.9212, 0.9546, 0.9023],
#        requires_grad=True)
# encoder.layer.3.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0951,  0.0145, -0.0806,  ...,  0.1077, -0.0328,  0.0170],
#        requires_grad=True)
# encoder.layer.4.attention.self.query.weight Parameter containing:
# tensor([[ 0.0530,  0.0253, -0.0425,  ..., -0.0031, -0.0173,  0.0009],
#         [ 0.0078, -0.0295,  0.0476,  ...,  0.0054,  0.0179, -0.0143],
#         [-0.0204,  0.0058, -0.0300,  ...,  0.0261, -0.0198, -0.0282],
#         ...,
#         [-0.0602,  0.0136,  0.0719,  ..., -0.0060,  0.0265, -0.0351],
#         [ 0.0134,  0.0230,  0.0537,  ...,  0.0125, -0.0040,  0.0259],
#         [ 0.0509, -0.0721,  0.0021,  ..., -0.0122, -0.0165,  0.0202]],
#        requires_grad=True)
# encoder.layer.4.attention.self.query.bias Parameter containing:
# tensor([ 0.0241, -0.0355,  0.0524,  ..., -0.0120, -0.0075, -0.0178],
#        requires_grad=True)
# encoder.layer.4.attention.self.key.weight Parameter containing:
# tensor([[-0.0608, -0.0087,  0.0294,  ..., -0.0335, -0.0069,  0.0079],
#         [-0.0103, -0.0190,  0.0180,  ..., -0.0310,  0.0395, -0.0228],
#         [ 0.0095,  0.0355, -0.0225,  ..., -0.0513, -0.0216, -0.0086],
#         ...,
#         [-0.0108, -0.0250, -0.0656,  ..., -0.0120,  0.0168, -0.0209],
#         [ 0.0131,  0.0013, -0.0340,  ...,  0.0546, -0.0262, -0.0383],
#         [ 0.0288,  0.0004,  0.0550,  ...,  0.0341,  0.0079, -0.0253]],
#        requires_grad=True)
# encoder.layer.4.attention.self.key.bias Parameter containing:
# tensor([ 0.0033, -0.0024, -0.0048,  ...,  0.0006, -0.0022, -0.0015],
#        requires_grad=True)
# encoder.layer.4.attention.self.value.weight Parameter containing:
# tensor([[-0.0064, -0.0043, -0.0105,  ..., -0.0128, -0.0053,  0.0382],
#         [ 0.0315,  0.0068, -0.0335,  ...,  0.0009, -0.0258, -0.0180],
#         [ 0.0067, -0.0300, -0.0026,  ..., -0.0014,  0.0311,  0.0042],
#         ...,
#         [-0.0027, -0.0255,  0.0222,  ..., -0.0334,  0.0372,  0.0377],
#         [ 0.0177, -0.0309, -0.0185,  ...,  0.0163,  0.0260,  0.0514],
#         [ 0.0541,  0.0411, -0.0113,  ...,  0.0149,  0.0464,  0.0200]],
#        requires_grad=True)
# encoder.layer.4.attention.self.value.bias Parameter containing:
# tensor([ 0.0179,  0.0049, -0.0072,  ...,  0.0087,  0.0166,  0.0076],
#        requires_grad=True)
# encoder.layer.4.attention.output.dense.weight Parameter containing:
# tensor([[-0.0118,  0.0030,  0.0027,  ..., -0.0005, -0.0188, -0.0200],
#         [ 0.0426, -0.0525, -0.0046,  ...,  0.0063,  0.0036,  0.0163],
#         [ 0.0049,  0.0056, -0.0184,  ..., -0.0022, -0.0355,  0.0203],
#         ...,
#         [ 0.0014,  0.0051,  0.0058,  ...,  0.0003, -0.0510, -0.0103],
#         [ 0.0433,  0.0130, -0.0071,  ..., -0.0029, -0.0097, -0.0122],
#         [-0.0344,  0.0033,  0.0187,  ..., -0.0442,  0.0155, -0.0162]],
#        requires_grad=True)
# encoder.layer.4.attention.output.dense.bias Parameter containing:
# tensor([ 0.0204, -0.0005, -0.0127,  ...,  0.0041,  0.0086,  0.0316],
#        requires_grad=True)
# encoder.layer.4.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.9762, 0.9503, 0.9849,  ..., 0.9656, 0.9678, 0.9498],
#        requires_grad=True)
# encoder.layer.4.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.1244,  0.0591,  0.2191,  ...,  0.0481, -0.0330,  0.0582],
#        requires_grad=True)
# encoder.layer.4.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0482,  0.0069,  0.0587,  ...,  0.0350,  0.0263,  0.0033],
#         [ 0.0152, -0.0267,  0.0015,  ..., -0.0402, -0.0116, -0.0191],
#         [-0.0368,  0.0439,  0.0114,  ..., -0.0181,  0.0170, -0.0074],
#         ...,
#         [-0.0109, -0.0160,  0.0616,  ..., -0.0268,  0.0283,  0.0077],
#         [-0.0250,  0.0177,  0.0118,  ...,  0.0178, -0.0553, -0.0151],
#         [ 0.0549, -0.0187, -0.0122,  ..., -0.0305, -0.0082,  0.0056]],
#        requires_grad=True)
# encoder.layer.4.intermediate.dense.bias Parameter containing:
# tensor([-0.0541, -0.0682, -0.0310,  ..., -0.0501, -0.0513, -0.0410],
#        requires_grad=True)
# encoder.layer.4.output.dense.weight Parameter containing:
# tensor([[-0.0353,  0.0157,  0.0063,  ..., -0.0536,  0.0280, -0.0262],
#         [-0.0274, -0.0558,  0.0018,  ..., -0.0570, -0.0176, -0.0011],
#         [-0.0313, -0.0128, -0.0156,  ..., -0.0206,  0.0583,  0.0625],
#         ...,
#         [ 0.0751,  0.0310, -0.0277,  ..., -0.0072, -0.0035, -0.0273],
#         [ 0.0031,  0.0256,  0.0207,  ..., -0.0271, -0.0137, -0.0100],
#         [ 0.0055, -0.0179,  0.0185,  ...,  0.0045, -0.0185, -0.0412]],
#        requires_grad=True)
# encoder.layer.4.output.dense.bias Parameter containing:
# tensor([-0.0333,  0.0290, -0.0072,  ...,  0.0728, -0.0235, -0.0208],
#        requires_grad=True)
# encoder.layer.4.output.LayerNorm.weight Parameter containing:
# tensor([0.9173, 0.9286, 0.8971,  ..., 0.9417, 0.9601, 0.9048],
#        requires_grad=True)
# encoder.layer.4.output.LayerNorm.bias Parameter containing:
# tensor([ 0.1147, -0.0026, -0.0614,  ...,  0.0461,  0.0067,  0.0371],
#        requires_grad=True)
# encoder.layer.5.attention.self.query.weight Parameter containing:
# tensor([[ 0.0183, -0.0205, -0.0345,  ..., -0.0013, -0.0203,  0.0330],
#         [ 0.0047, -0.0501,  0.0479,  ...,  0.0382, -0.0268, -0.0097],
#         [ 0.0048,  0.0450, -0.0008,  ..., -0.0224, -0.0002,  0.0783],
#         ...,
#         [ 0.0007,  0.0569, -0.0415,  ..., -0.0172, -0.0034,  0.0094],
#         [ 0.0328,  0.0158, -0.0550,  ...,  0.0038, -0.0220,  0.0103],
#         [-0.0212, -0.0271,  0.0289,  ...,  0.0157, -0.0383, -0.0436]],
#        requires_grad=True)
# encoder.layer.5.attention.self.query.bias Parameter containing:
# tensor([-0.0450,  0.0212, -0.0414,  ..., -0.0359,  0.0057, -0.0394],
#        requires_grad=True)
# encoder.layer.5.attention.self.key.weight Parameter containing:
# tensor([[ 0.0320, -0.0578, -0.0143,  ...,  0.0205,  0.0186,  0.0136],
#         [-0.0171, -0.0353,  0.0423,  ...,  0.0029,  0.0097,  0.0345],
#         [ 0.0181, -0.0078, -0.0272,  ...,  0.0233, -0.0217,  0.0379],
#         ...,
#         [-0.0425, -0.0374,  0.0257,  ...,  0.0105,  0.0272,  0.0024],
#         [ 0.0155,  0.0194,  0.0312,  ...,  0.0246,  0.0243,  0.0033],
#         [ 0.0090, -0.0100,  0.0103,  ...,  0.0154,  0.0214,  0.0429]],
#        requires_grad=True)
# encoder.layer.5.attention.self.key.bias Parameter containing:
# tensor([-0.0004,  0.0005,  0.0006,  ..., -0.0046,  0.0070, -0.0073],
#        requires_grad=True)
# encoder.layer.5.attention.self.value.weight Parameter containing:
# tensor([[ 0.0329, -0.0270,  0.0240,  ..., -0.0203,  0.0326,  0.0146],
#         [-0.0072, -0.0123, -0.0305,  ...,  0.0113, -0.0314,  0.0512],
#         [ 0.0327, -0.0276,  0.0199,  ..., -0.0044,  0.0058, -0.0037],
#         ...,
#         [-0.0354,  0.0004, -0.0134,  ..., -0.0325,  0.0195,  0.0136],
#         [-0.0818,  0.0013, -0.0037,  ...,  0.0002, -0.0345, -0.0010],
#         [-0.0251,  0.0503, -0.0232,  ...,  0.0165, -0.0021, -0.0038]],
#        requires_grad=True)
# encoder.layer.5.attention.self.value.bias Parameter containing:
# tensor([-0.0081,  0.0049,  0.0094,  ..., -0.0048,  0.0041, -0.0148],
#        requires_grad=True)
# encoder.layer.5.attention.output.dense.weight Parameter containing:
# tensor([[-0.0092,  0.0220, -0.0128,  ..., -0.0259, -0.0310,  0.0171],
#         [ 0.0383,  0.0119,  0.0542,  ...,  0.0320, -0.0033, -0.0124],
#         [ 0.0441, -0.0002, -0.0119,  ..., -0.0250,  0.0252, -0.0442],
#         ...,
#         [-0.0100,  0.0278, -0.0215,  ..., -0.0084,  0.0095, -0.0603],
#         [ 0.0427,  0.0013,  0.0131,  ..., -0.0093,  0.0055,  0.0226],
#         [-0.0433,  0.0068, -0.0016,  ...,  0.0462,  0.0276, -0.0145]],
#        requires_grad=True)
# encoder.layer.5.attention.output.dense.bias Parameter containing:
# tensor([-0.0153,  0.0147,  0.0063,  ...,  0.0168, -0.0151,  0.0056],
#        requires_grad=True)
# encoder.layer.5.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.9539, 0.9351, 0.9821,  ..., 0.9435, 0.9573, 0.9292],
#        requires_grad=True)
# encoder.layer.5.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.1253,  0.0572,  0.2918,  ...,  0.0628, -0.1274,  0.1278],
#        requires_grad=True)
# encoder.layer.5.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0281,  0.0170, -0.0311,  ..., -0.0490, -0.0038, -0.0092],
#         [ 0.0251,  0.0066,  0.0187,  ...,  0.0047,  0.0101, -0.0108],
#         [-0.0830, -0.0219, -0.0307,  ..., -0.0312,  0.0072, -0.0218],
#         ...,
#         [ 0.0858,  0.0060, -0.0488,  ...,  0.0604,  0.0463, -0.0154],
#         [-0.0812, -0.0392, -0.0690,  ...,  0.0767, -0.0087, -0.0515],
#         [-0.0036,  0.0253,  0.0316,  ..., -0.0166,  0.0481, -0.0249]],
#        requires_grad=True)
# encoder.layer.5.intermediate.dense.bias Parameter containing:
# tensor([-0.0559, -0.0603, -0.0565,  ..., -0.0536, -0.0576, -0.0685],
#        requires_grad=True)
# encoder.layer.5.output.dense.weight Parameter containing:
# tensor([[-0.0285,  0.0434, -0.0244,  ...,  0.0051, -0.0525, -0.0122],
#         [ 0.0201,  0.0696, -0.0003,  ...,  0.0086, -0.0074, -0.0500],
#         [-0.0026, -0.0032,  0.0177,  ...,  0.0193,  0.0044, -0.0195],
#         ...,
#         [ 0.0208, -0.0036, -0.0135,  ...,  0.0117,  0.0226,  0.0176],
#         [-0.0092, -0.0075, -0.0115,  ..., -0.0301, -0.0428,  0.0019],
#         [ 0.0289, -0.0251,  0.0050,  ...,  0.0171, -0.0217,  0.0120]],
#        requires_grad=True)
# encoder.layer.5.output.dense.bias Parameter containing:
# tensor([ 0.0063,  0.0016, -0.0028,  ...,  0.0771, -0.0376,  0.0196],
#        requires_grad=True)
# encoder.layer.5.output.LayerNorm.weight Parameter containing:
# tensor([0.8778, 0.8938, 0.8508,  ..., 0.9048, 0.9220, 0.8734],
#        requires_grad=True)
# encoder.layer.5.output.LayerNorm.bias Parameter containing:
# tensor([ 0.1088, -0.0068, -0.0650,  ...,  0.0521,  0.0519, -0.0059],
#        requires_grad=True)
# encoder.layer.6.attention.self.query.weight Parameter containing:
# tensor([[ 0.0327,  0.0428, -0.0450,  ..., -0.0749, -0.0086, -0.0152],
#         [ 0.0233, -0.0023,  0.0158,  ..., -0.0134, -0.0489,  0.0517],
#         [ 0.0098, -0.0062, -0.0324,  ...,  0.0356, -0.0829,  0.0182],
#         ...,
#         [ 0.0788,  0.0426, -0.0397,  ...,  0.0409, -0.0337,  0.0497],
#         [ 0.0133,  0.0052, -0.0163,  ..., -0.0279, -0.0208,  0.0040],
#         [ 0.0190,  0.0382,  0.0127,  ...,  0.0090, -0.0045,  0.0096]],
#        requires_grad=True)
# encoder.layer.6.attention.self.query.bias Parameter containing:
# tensor([ 0.0307, -0.0209, -0.0252,  ..., -0.0358, -0.0292,  0.1060],
#        requires_grad=True)
# encoder.layer.6.attention.self.key.weight Parameter containing:
# tensor([[ 0.0129,  0.0835,  0.0135,  ..., -0.0549,  0.0710,  0.0189],
#         [ 0.0486, -0.0157, -0.0013,  ...,  0.0665, -0.0484,  0.0509],
#         [-0.0004,  0.0873, -0.0199,  ...,  0.0302, -0.0547,  0.0593],
#         ...,
#         [ 0.0734,  0.0356, -0.0932,  ..., -0.0288, -0.1301,  0.0427],
#         [-0.0016, -0.0409,  0.0231,  ..., -0.0218, -0.0140,  0.0128],
#         [ 0.0133, -0.0032, -0.0503,  ..., -0.0029,  0.0482, -0.0301]],
#        requires_grad=True)
# encoder.layer.6.attention.self.key.bias Parameter containing:
# tensor([ 0.0059, -0.0055, -0.0027,  ..., -0.0022, -0.0035, -0.0026],
#        requires_grad=True)
# encoder.layer.6.attention.self.value.weight Parameter containing:
# tensor([[-0.0212, -0.0193, -0.0147,  ..., -0.0069,  0.0303,  0.0315],
#         [-0.0083, -0.0020, -0.0018,  ..., -0.0025, -0.0017, -0.0071],
#         [ 0.0008, -0.0221, -0.0338,  ...,  0.0352, -0.0045, -0.0018],
#         ...,
#         [-0.0234, -0.0430, -0.0120,  ..., -0.0490,  0.0011, -0.0148],
#         [-0.0380,  0.0245, -0.0455,  ...,  0.0081,  0.0124,  0.0549],
#         [ 0.0120, -0.0083,  0.0224,  ..., -0.0128, -0.0061,  0.0146]],
#        requires_grad=True)
# encoder.layer.6.attention.self.value.bias Parameter containing:
# tensor([-0.0014, -0.0083,  0.0003,  ...,  0.0074, -0.0082, -0.0132],
#        requires_grad=True)
# encoder.layer.6.attention.output.dense.weight Parameter containing:
# tensor([[ 0.0323, -0.0468, -0.0014,  ...,  0.0136,  0.0125, -0.0282],
#         [-0.0359,  0.0206, -0.0399,  ...,  0.0466,  0.0170,  0.0116],
#         [-0.0044,  0.0024, -0.0693,  ...,  0.0021,  0.0149, -0.0245],
#         ...,
#         [-0.0163, -0.0025, -0.0183,  ...,  0.0198,  0.0138,  0.0176],
#         [ 0.0325,  0.0186, -0.0024,  ..., -0.0192, -0.0088,  0.0092],
#         [-0.0454,  0.0584, -0.0047,  ...,  0.0161, -0.0120, -0.0543]],
#        requires_grad=True)
# encoder.layer.6.attention.output.dense.bias Parameter containing:
# tensor([-0.0137, -0.0117,  0.0426,  ...,  0.0248, -0.0060,  0.0177],
#        requires_grad=True)
# encoder.layer.6.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.9451, 0.9476, 0.9945,  ..., 0.9593, 0.9639, 0.9286],
#        requires_grad=True)
# encoder.layer.6.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0144, -0.0642,  0.2680,  ...,  0.1310, -0.1312,  0.0828],
#        requires_grad=True)
# encoder.layer.6.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0212, -0.0169,  0.0372,  ...,  0.0432, -0.0228, -0.0374],
#         [ 0.0521,  0.0092, -0.0439,  ...,  0.0267, -0.0718, -0.0419],
#         [-0.0066, -0.0084,  0.0308,  ...,  0.0162, -0.1043, -0.0670],
#         ...,
#         [ 0.0232,  0.0059, -0.0237,  ..., -0.0050, -0.0309,  0.0133],
#         [ 0.0479,  0.0032, -0.0361,  ...,  0.0248,  0.0165,  0.0130],
#         [ 0.0877,  0.0374,  0.0280,  ...,  0.0483, -0.0150, -0.0216]],
#        requires_grad=True)
# encoder.layer.6.intermediate.dense.bias Parameter containing:
# tensor([-0.0479, -0.0817, -0.0709,  ...,  0.0318, -0.0599, -0.0745],
#        requires_grad=True)
# encoder.layer.6.output.dense.weight Parameter containing:
# tensor([[ 0.0309,  0.0189, -0.0134,  ...,  0.0148, -0.0722,  0.0515],
#         [-0.0274, -0.0556, -0.0055,  ...,  0.0347,  0.0030,  0.0271],
#         [-0.0396,  0.0031, -0.0374,  ...,  0.0338,  0.0651,  0.0299],
#         ...,
#         [ 0.0393, -0.0033, -0.0024,  ...,  0.0384, -0.0318,  0.0215],
#         [ 0.0041, -0.0230,  0.0443,  ...,  0.0048, -0.0155,  0.0205],
#         [-0.0099,  0.0077, -0.0013,  ...,  0.0282, -0.0027,  0.0180]],
#        requires_grad=True)
# encoder.layer.6.output.dense.bias Parameter containing:
# tensor([ 0.0135,  0.0333, -0.0458,  ...,  0.0396, -0.0341,  0.0031],
#        requires_grad=True)
# encoder.layer.6.output.LayerNorm.weight Parameter containing:
# tensor([0.8744, 0.8771, 0.8461,  ..., 0.8877, 0.8948, 0.8590],
#        requires_grad=True)
# encoder.layer.6.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0482,  0.0233, -0.0764,  ...,  0.0029,  0.0771, -0.0054],
#        requires_grad=True)
# encoder.layer.7.attention.self.query.weight Parameter containing:
# tensor([[-0.0310, -0.0051,  0.0160,  ..., -0.0097, -0.0123,  0.0030],
#         [-0.0285,  0.0226,  0.0027,  ..., -0.0361,  0.0462, -0.0554],
#         [ 0.0164, -0.0038,  0.0302,  ...,  0.0111,  0.0213, -0.0114],
#         ...,
#         [ 0.0133, -0.0024,  0.0017,  ...,  0.0355,  0.0050,  0.0708],
#         [-0.0070,  0.0270,  0.0048,  ..., -0.0140, -0.0463, -0.0751],
#         [ 0.0369,  0.0275, -0.0102,  ..., -0.0124,  0.0271,  0.0168]],
#        requires_grad=True)
# encoder.layer.7.attention.self.query.bias Parameter containing:
# tensor([-0.1106,  0.0538, -0.0676,  ...,  0.0677,  0.0745,  0.0282],
#        requires_grad=True)
# encoder.layer.7.attention.self.key.weight Parameter containing:
# tensor([[ 3.7770e-02,  7.8896e-03,  1.0102e-02,  ...,  9.4997e-03,
#           6.5811e-02,  3.2593e-02],
#         [-5.8926e-02,  5.2928e-02,  5.3857e-03,  ..., -4.2257e-03,
#           4.2505e-02,  5.9289e-02],
#         [ 8.7261e-02, -2.2979e-02,  1.7355e-02,  ...,  1.9022e-02,
#           4.6322e-02, -1.3533e-05],
#         ...,
#         [-7.3140e-04, -4.5663e-02,  8.4963e-03,  ...,  1.7330e-02,
#          -4.6019e-02, -7.8726e-03],
#         [-3.1607e-02,  6.2398e-02, -1.4606e-04,  ...,  2.1339e-03,
#          -2.8158e-02,  4.2171e-02],
#         [ 4.5119e-02,  6.5648e-04,  1.7110e-02,  ...,  1.0086e-02,
#          -9.2409e-03, -1.6384e-02]], requires_grad=True)
# encoder.layer.7.attention.self.key.bias Parameter containing:
# tensor([ 0.0014,  0.0015, -0.0006,  ..., -0.0027, -0.0006,  0.0005],
#        requires_grad=True)
# encoder.layer.7.attention.self.value.weight Parameter containing:
# tensor([[ 0.0054, -0.0212,  0.0070,  ..., -0.0419, -0.0233,  0.0108],
#         [-0.0001, -0.0169,  0.0337,  ...,  0.0037, -0.0402, -0.0074],
#         [-0.0433, -0.0084,  0.0247,  ..., -0.0092, -0.0517, -0.0132],
#         ...,
#         [ 0.0128,  0.0079,  0.0321,  ..., -0.0100,  0.0057,  0.0480],
#         [-0.0337, -0.0146,  0.0048,  ...,  0.0314, -0.0113, -0.0005],
#         [-0.0596, -0.0312,  0.0308,  ...,  0.0067,  0.0258, -0.0601]],
#        requires_grad=True)
# encoder.layer.7.attention.self.value.bias Parameter containing:
# tensor([ 0.0250, -0.0129,  0.0113,  ...,  0.0116, -0.0047,  0.0090],
#        requires_grad=True)
# encoder.layer.7.attention.output.dense.weight Parameter containing:
# tensor([[ 0.0387,  0.0246,  0.0454,  ..., -0.0088, -0.0026,  0.0588],
#         [-0.0452, -0.0308, -0.0392,  ...,  0.0111,  0.0274,  0.0551],
#         [-0.0043, -0.0030,  0.0059,  ..., -0.0173,  0.0023, -0.0158],
#         ...,
#         [ 0.0006, -0.0082, -0.0202,  ..., -0.0483, -0.0163, -0.0055],
#         [-0.0066,  0.0218, -0.0096,  ..., -0.0089, -0.0097,  0.0101],
#         [-0.0209,  0.0293,  0.0121,  ...,  0.0028,  0.0376,  0.0142]],
#        requires_grad=True)
# encoder.layer.7.attention.output.dense.bias Parameter containing:
# tensor([ 0.0008,  0.0018,  0.0349,  ...,  0.0149, -0.0073,  0.0137],
#        requires_grad=True)
# encoder.layer.7.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.9376, 0.9713, 1.0231,  ..., 0.9826, 0.9883, 0.9513],
#        requires_grad=True)
# encoder.layer.7.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0128, -0.1441,  0.2572,  ...,  0.1779, -0.1139,  0.0834],
#        requires_grad=True)
# encoder.layer.7.intermediate.dense.weight Parameter containing:
# tensor([[-0.0283, -0.0013, -0.0826,  ..., -0.0511,  0.0345, -0.0613],
#         [ 0.0686,  0.0112, -0.0418,  ..., -0.0731,  0.0032, -0.0287],
#         [ 0.0436,  0.0107,  0.0467,  ..., -0.0426, -0.0266, -0.0113],
#         ...,
#         [ 0.0267, -0.0166,  0.0002,  ..., -0.0260,  0.0364, -0.0126],
#         [-0.0315, -0.0283, -0.0365,  ...,  0.0318, -0.0083,  0.0556],
#         [-0.0141, -0.0290, -0.0328,  ..., -0.0038,  0.0434, -0.0519]],
#        requires_grad=True)
# encoder.layer.7.intermediate.dense.bias Parameter containing:
# tensor([-0.0705, -0.0617, -0.0680,  ..., -0.0651, -0.0739, -0.0716],
#        requires_grad=True)
# encoder.layer.7.output.dense.weight Parameter containing:
# tensor([[-0.0191, -0.0007,  0.0728,  ...,  0.0490, -0.0489, -0.0187],
#         [ 0.0117, -0.0379,  0.0282,  ...,  0.0282, -0.0496, -0.0650],
#         [-0.0525,  0.0648, -0.0036,  ...,  0.0718, -0.0017,  0.0341],
#         ...,
#         [-0.0321, -0.0121,  0.0190,  ...,  0.0179, -0.0113, -0.0145],
#         [-0.0059, -0.0174, -0.0123,  ...,  0.0479, -0.0167,  0.0627],
#         [-0.0061, -0.0025, -0.0357,  ..., -0.0194,  0.0339,  0.0290]],
#        requires_grad=True)
# encoder.layer.7.output.dense.bias Parameter containing:
# tensor([ 0.0151,  0.0405, -0.0587,  ...,  0.0366,  0.0051,  0.0213],
#        requires_grad=True)
# encoder.layer.7.output.LayerNorm.weight Parameter containing:
# tensor([0.8929, 0.8861, 0.8585,  ..., 0.8940, 0.9277, 0.8695],
#        requires_grad=True)
# encoder.layer.7.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0182,  0.0538, -0.1402,  ..., -0.0719,  0.0840, -0.0607],
#        requires_grad=True)
# encoder.layer.8.attention.self.query.weight Parameter containing:
# tensor([[-0.0232,  0.0977, -0.0923,  ..., -0.0231, -0.0518,  0.0158],
#         [ 0.0193, -0.0182, -0.0159,  ...,  0.0264, -0.0404,  0.0324],
#         [ 0.0320,  0.0058, -0.0543,  ..., -0.0479,  0.0027,  0.0390],
#         ...,
#         [-0.0081, -0.0060, -0.0115,  ...,  0.0169, -0.0121,  0.0137],
#         [-0.0072, -0.0287,  0.0201,  ..., -0.0286,  0.0421, -0.0040],
#         [-0.0347, -0.0045,  0.0089,  ...,  0.0077,  0.0175, -0.0224]],
#        requires_grad=True)
# encoder.layer.8.attention.self.query.bias Parameter containing:
# tensor([ 0.1091,  0.0100,  0.3772,  ..., -0.0221,  0.0223, -0.0586],
#        requires_grad=True)
# encoder.layer.8.attention.self.key.weight Parameter containing:
# tensor([[ 0.0412, -0.0049, -0.0063,  ..., -0.0287, -0.0257,  0.0084],
#         [ 0.0092,  0.0346,  0.0095,  ...,  0.0137,  0.0353, -0.0168],
#         [-0.0241, -0.0070,  0.0162,  ...,  0.0276, -0.0562,  0.0075],
#         ...,
#         [ 0.0527,  0.0289, -0.0316,  ..., -0.0269, -0.0193, -0.0293],
#         [ 0.0084, -0.0256,  0.0362,  ...,  0.0569,  0.0512, -0.0160],
#         [-0.0223,  0.0117,  0.0510,  ..., -0.0416,  0.0145, -0.0176]],
#        requires_grad=True)
# encoder.layer.8.attention.self.key.bias Parameter containing:
# tensor([ 4.4108e-04, -9.1703e-05, -6.6812e-03,  ..., -2.2014e-04,
#          2.0029e-03, -7.0794e-04], requires_grad=True)
# encoder.layer.8.attention.self.value.weight Parameter containing:
# tensor([[-0.0002, -0.0967, -0.0116,  ..., -0.0121, -0.0324,  0.0275],
#         [-0.0098,  0.0113, -0.0253,  ...,  0.0225,  0.0014,  0.0309],
#         [ 0.0024,  0.0226, -0.0267,  ..., -0.0622, -0.0120,  0.0309],
#         ...,
#         [ 0.0231,  0.0277, -0.0249,  ..., -0.0090, -0.0267,  0.0175],
#         [-0.0288, -0.0733,  0.0248,  ..., -0.0058,  0.0364, -0.0173],
#         [-0.0540, -0.0009,  0.0034,  ..., -0.0081, -0.0078,  0.0048]],
#        requires_grad=True)
# encoder.layer.8.attention.self.value.bias Parameter containing:
# tensor([-0.0073,  0.0110, -0.0173,  ...,  0.0033,  0.0163, -0.0009],
#        requires_grad=True)
# encoder.layer.8.attention.output.dense.weight Parameter containing:
# tensor([[ 0.0352,  0.0059,  0.0142,  ..., -0.0155,  0.0206,  0.0516],
#         [ 0.0269, -0.0124, -0.0538,  ..., -0.0191,  0.0531,  0.0158],
#         [ 0.0309,  0.0582,  0.0102,  ..., -0.0031, -0.0311,  0.0051],
#         ...,
#         [-0.0433,  0.0169,  0.0259,  ...,  0.0032, -0.0188,  0.0459],
#         [ 0.0315, -0.0366,  0.0125,  ...,  0.0326, -0.0210, -0.0242],
#         [ 0.0205, -0.0334, -0.0326,  ...,  0.0184, -0.0074,  0.0097]],
#        requires_grad=True)
# encoder.layer.8.attention.output.dense.bias Parameter containing:
# tensor([ 0.0213,  0.0111, -0.0015,  ..., -0.0107, -0.0102, -0.0075],
#        requires_grad=True)
# encoder.layer.8.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.9414, 0.9569, 0.9890,  ..., 0.9671, 0.9880, 0.9333],
#        requires_grad=True)
# encoder.layer.8.attention.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0623, -0.0752,  0.2329,  ...,  0.1478, -0.0572,  0.0413],
#        requires_grad=True)
# encoder.layer.8.intermediate.dense.weight Parameter containing:
# tensor([[-0.0046,  0.0224,  0.0335,  ...,  0.0071,  0.0039, -0.0265],
#         [-0.0116,  0.0148,  0.0460,  ..., -0.0584, -0.0427, -0.0038],
#         [ 0.0308, -0.0002,  0.0260,  ..., -0.0043,  0.0083, -0.0637],
#         ...,
#         [-0.0876,  0.0263,  0.0059,  ...,  0.0397, -0.0074, -0.0322],
#         [-0.0212,  0.0009, -0.0089,  ...,  0.0196,  0.0259, -0.0083],
#         [ 0.0119,  0.0419, -0.0199,  ..., -0.0627,  0.0968, -0.0577]],
#        requires_grad=True)
# encoder.layer.8.intermediate.dense.bias Parameter containing:
# tensor([-0.0595, -0.0678, -0.0633,  ..., -0.0648, -0.0565, -0.0612],
#        requires_grad=True)
# encoder.layer.8.output.dense.weight Parameter containing:
# tensor([[ 0.0057, -0.0072, -0.0052,  ...,  0.0012, -0.0240,  0.0434],
#         [-0.0112,  0.0116,  0.0157,  ...,  0.0172, -0.0048,  0.0245],
#         [ 0.0186, -0.0193,  0.0318,  ..., -0.0074, -0.0039, -0.0128],
#         ...,
#         [-0.0486,  0.0288, -0.0630,  ...,  0.0865, -0.0123, -0.0209],
#         [ 0.0482,  0.0033, -0.0258,  ..., -0.0153,  0.0112,  0.0127],
#         [-0.0294, -0.0116, -0.0322,  ...,  0.0101, -0.1396,  0.0351]],
#        requires_grad=True)
# encoder.layer.8.output.dense.bias Parameter containing:
# tensor([ 0.0061,  0.0209, -0.0293,  ...,  0.0120, -0.0068,  0.0177],
#        requires_grad=True)
# encoder.layer.8.output.LayerNorm.weight Parameter containing:
# tensor([0.9290, 0.9373, 0.9069,  ..., 0.9473, 0.9934, 0.9036],
#        requires_grad=True)
# encoder.layer.8.output.LayerNorm.bias Parameter containing:
# tensor([-0.0589,  0.0077, -0.1530,  ..., -0.1121,  0.0355, -0.0659],
#        requires_grad=True)
# encoder.layer.9.attention.self.query.weight Parameter containing:
# tensor([[ 0.0486,  0.0524,  0.0107,  ..., -0.0196, -0.0245,  0.0057],
#         [ 0.0155, -0.0113, -0.0085,  ...,  0.0677, -0.0767,  0.0140],
#         [ 0.0567,  0.1233,  0.0081,  ..., -0.0681, -0.0477, -0.0055],
#         ...,
#         [ 0.0327,  0.0333, -0.0173,  ...,  0.0771, -0.0206, -0.0186],
#         [-0.0339,  0.0026,  0.0288,  ..., -0.0676,  0.0025,  0.0375],
#         [ 0.0340, -0.0550,  0.0568,  ..., -0.0209, -0.0040,  0.0061]],
#        requires_grad=True)
# encoder.layer.9.attention.self.query.bias Parameter containing:
# tensor([-0.0313,  0.0450,  0.0471,  ..., -0.1672,  0.1561, -0.3205],
#        requires_grad=True)
# encoder.layer.9.attention.self.key.weight Parameter containing:
# tensor([[ 3.6360e-02, -2.5708e-02,  1.6931e-02,  ..., -1.0053e-02,
#           8.9737e-03, -3.3915e-02],
#         [ 9.9450e-03, -4.3323e-02,  2.5615e-03,  ...,  1.8223e-02,
#          -4.9840e-02,  2.1404e-02],
#         [-4.8856e-02,  5.5082e-02, -5.5244e-02,  ...,  5.0998e-05,
#          -4.1442e-02,  1.0893e-02],
#         ...,
#         [-6.3390e-03, -8.4831e-02,  3.4318e-04,  ...,  1.8429e-02,
#           3.3636e-02, -1.6249e-02],
#         [-1.6190e-02,  1.4430e-02, -1.0519e-02,  ..., -1.1226e-02,
#          -3.7575e-02, -1.9620e-03],
#         [ 1.1188e-02,  6.3196e-03, -2.1819e-02,  ..., -6.5015e-03,
#           4.6999e-03,  8.6173e-03]], requires_grad=True)
# encoder.layer.9.attention.self.key.bias Parameter containing:
# tensor([ 4.5914e-03, -2.7998e-03, -8.8724e-03,  ...,  1.5268e-04,
#         -1.9326e-05,  8.1172e-04], requires_grad=True)
# encoder.layer.9.attention.self.value.weight Parameter containing:
# tensor([[-4.1022e-02, -4.3006e-02, -8.8818e-05,  ..., -4.3832e-03,
#          -2.9209e-02, -1.1038e-02],
#         [-2.9856e-02, -1.5393e-02,  2.7208e-02,  ..., -2.0063e-03,
#           4.5717e-03,  2.5801e-02],
#         [ 2.1817e-02, -5.2769e-03,  1.3679e-02,  ...,  5.2868e-02,
#           1.2223e-02, -3.5320e-02],
#         ...,
#         [-8.7628e-03,  8.5406e-03, -2.1403e-02,  ..., -1.2688e-02,
#           3.6071e-02,  1.8519e-02],
#         [-1.0762e-02, -2.5196e-02,  1.5549e-02,  ..., -1.1992e-02,
#          -1.8076e-02,  1.0748e-02],
#         [-2.4324e-02, -7.1958e-03,  6.1110e-03,  ...,  3.4228e-02,
#          -3.2521e-03, -1.2226e-02]], requires_grad=True)
# encoder.layer.9.attention.self.value.bias Parameter containing:
# tensor([ 0.0396,  0.0203, -0.0422,  ..., -0.0288,  0.0182, -0.0275],
#        requires_grad=True)
# encoder.layer.9.attention.output.dense.weight Parameter containing:
# tensor([[-0.0031,  0.0197, -0.0225,  ...,  0.0162,  0.0158,  0.0168],
#         [ 0.0274,  0.0107, -0.0046,  ..., -0.0025,  0.0069, -0.0234],
#         [-0.0240, -0.0532, -0.0513,  ...,  0.0455, -0.0345, -0.0200],
#         ...,
#         [-0.0124, -0.0157, -0.0270,  ..., -0.0111, -0.0237, -0.0198],
#         [ 0.0230, -0.0192, -0.0002,  ..., -0.0008, -0.0157,  0.0051],
#         [-0.0091, -0.0142, -0.0038,  ..., -0.0063,  0.0176, -0.0276]],
#        requires_grad=True)
# encoder.layer.9.attention.output.dense.bias Parameter containing:
# tensor([-0.0053,  0.0587, -0.0145,  ...,  0.0694, -0.0394,  0.0124],
#        requires_grad=True)
# encoder.layer.9.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.9398, 0.9498, 0.9914,  ..., 0.9652, 0.9799, 0.9420],
#        requires_grad=True)
# encoder.layer.9.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0300, -0.0891,  0.2048,  ...,  0.1037,  0.0023, -0.0205],
#        requires_grad=True)
# encoder.layer.9.intermediate.dense.weight Parameter containing:
# ...
#         [ 0.0166,  0.0041, -0.0345,  ..., -0.0020,  0.0115, -0.0245],
#         [ 0.0126, -0.0634,  0.0330,  ..., -0.0405,  0.0504, -0.0055],
#         ...,
#         [ 0.0031,  0.0016, -0.0088,  ..., -0.0357,  0.0225, -0.0397],
#         [ 0.0026, -0.0020, -0.0026,  ...,  0.0189,  0.0072,  0.0214],
#         [ 0.0117, -0.0163,  0.0014,  ...,  0.0411, -0.0228,  0.0306]],
#        requires_grad=True)
# encoder.layer.20.output.dense.bias Parameter containing:
# tensor([-0.0354, -0.0540, -0.0133,  ...,  0.0342, -0.0061,  0.0505],
#        requires_grad=True)
# encoder.layer.20.output.LayerNorm.weight Parameter containing:
# tensor([0.8713, 0.8788, 0.8821,  ..., 0.8960, 0.8872, 0.8679],
#        requires_grad=True)
# encoder.layer.20.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0182,  0.0217,  0.0041,  ..., -0.0154,  0.0142,  0.0058],
#        requires_grad=True)
# encoder.layer.21.attention.self.query.weight Parameter containing:
# tensor([[-0.0062,  0.0222, -0.0853,  ...,  0.0289,  0.0476,  0.0530],
#         [-0.0028, -0.0443, -0.0108,  ...,  0.0425, -0.0467,  0.0313],
#         [-0.0004, -0.0193, -0.0765,  ...,  0.0235, -0.0105,  0.0343],
#         ...,
#         [-0.0695,  0.0018,  0.0297,  ..., -0.0425, -0.0359, -0.0183],
#         [-0.0344,  0.0354,  0.0445,  ...,  0.0639, -0.0599, -0.0237],
#         [ 0.0559,  0.0086, -0.0125,  ..., -0.0230, -0.0240,  0.0111]],
#        requires_grad=True)
# encoder.layer.21.attention.self.query.bias Parameter containing:
# tensor([ 9.3205e-02,  1.1141e-01, -1.9864e-02,  ...,  1.0445e-04,
#          9.0266e-02, -1.5502e-01], requires_grad=True)
# encoder.layer.21.attention.self.key.weight Parameter containing:
# tensor([[-0.0418,  0.0454,  0.0334,  ..., -0.0185, -0.0205, -0.0361],
#         [ 0.0462, -0.0361,  0.0148,  ...,  0.0139, -0.0874, -0.0046],
#         [-0.0353, -0.0477, -0.0350,  ..., -0.0225,  0.0039,  0.0552],
#         ...,
#         [-0.0463, -0.0145,  0.0349,  ...,  0.0447,  0.0019,  0.0017],
#         [-0.0187,  0.0595,  0.0189,  ...,  0.0251,  0.0214, -0.0444],
#         [-0.0164, -0.0592, -0.0316,  ..., -0.0571, -0.0037, -0.0437]],
#        requires_grad=True)
# encoder.layer.21.attention.self.key.bias Parameter containing:
# tensor([ 0.0043,  0.0021, -0.0039,  ..., -0.0025,  0.0019,  0.0004],
#        requires_grad=True)
# encoder.layer.21.attention.self.value.weight Parameter containing:
# tensor([[-0.0352, -0.0731, -0.0216,  ...,  0.1062,  0.0419,  0.0153],
#         [-0.0101, -0.0069,  0.0463,  ..., -0.0090,  0.0136, -0.0520],
#         [-0.0428, -0.0055, -0.0268,  ...,  0.0165, -0.0015, -0.0232],
#         ...,
#         [ 0.0313, -0.0233, -0.0171,  ...,  0.0163, -0.0010,  0.0229],
#         [-0.0256, -0.0052, -0.0141,  ...,  0.0505, -0.0555, -0.0065],
#         [ 0.0712, -0.0285, -0.0096,  ..., -0.0645, -0.0455, -0.0371]],
#        requires_grad=True)
# encoder.layer.21.attention.self.value.bias Parameter containing:
# tensor([-0.0114,  0.0211,  0.0134,  ..., -0.0052,  0.0004,  0.0129],
#        requires_grad=True)
# encoder.layer.21.attention.output.dense.weight Parameter containing:
# tensor([[-0.0077,  0.0121,  0.0188,  ..., -0.0527, -0.0066, -0.0421],
#         [ 0.0317,  0.0004, -0.0324,  ..., -0.0084,  0.0215, -0.0473],
#         [-0.0066, -0.0053,  0.0355,  ...,  0.0100,  0.0119, -0.0239],
#         ...,
#         [ 0.0116,  0.0324, -0.0174,  ..., -0.0097, -0.0500, -0.0035],
#         [-0.0319, -0.0276, -0.0088,  ..., -0.0065,  0.0296, -0.0023],
#         [ 0.0074,  0.0191,  0.0695,  ..., -0.0385, -0.0108,  0.0468]],
#        requires_grad=True)
# encoder.layer.21.attention.output.dense.bias Parameter containing:
# tensor([-0.0066, -0.0711, -0.0169,  ..., -0.0305,  0.0178,  0.0074],
#        requires_grad=True)
# encoder.layer.21.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.8314, 0.8126, 0.8176,  ..., 0.7901, 0.8274, 0.8074],
#        requires_grad=True)
# encoder.layer.21.attention.output.LayerNorm.bias Parameter containing:
# tensor([-4.9163e-02, -3.8619e-02, -1.5965e-02,  ...,  3.2479e-02,
#         -4.4565e-06,  6.6333e-02], requires_grad=True)
# encoder.layer.21.intermediate.dense.weight Parameter containing:
# tensor([[ 2.1294e-02, -1.4662e-03, -4.1065e-02,  ...,  3.0575e-02,
#           1.5024e-05,  1.1022e-02],
#         [ 1.7756e-02,  3.7049e-02,  2.6278e-02,  ..., -3.9000e-02,
#           1.8214e-02, -1.7173e-02],
#         [-4.5715e-03,  5.4492e-02,  4.5252e-03,  ..., -2.1276e-02,
#           2.3224e-03, -6.4660e-02],
#         ...,
#         [ 6.8326e-02,  6.2117e-02,  8.7491e-03,  ..., -2.6476e-02,
#           1.4462e-02, -2.0708e-02],
#         [-2.9243e-03,  4.7225e-02,  7.1076e-02,  ...,  4.6272e-02,
#          -1.6826e-02,  1.1698e-02],
#         [ 1.1435e-02, -4.7138e-02,  1.3275e-02,  ...,  7.6388e-03,
#           2.8070e-03,  5.9110e-02]], requires_grad=True)
# encoder.layer.21.intermediate.dense.bias Parameter containing:
# tensor([-0.0746, -0.0845, -0.0803,  ..., -0.0616, -0.0224, -0.0538],
#        requires_grad=True)
# encoder.layer.21.output.dense.weight Parameter containing:
# tensor([[ 0.0070, -0.0139,  0.0047,  ...,  0.0225, -0.0421,  0.0098],
#         [ 0.0040,  0.0333, -0.0154,  ...,  0.0271,  0.0239, -0.0913],
#         [-0.0307, -0.0179,  0.0180,  ...,  0.0103, -0.0033,  0.0301],
#         ...,
#         [ 0.0387, -0.0255, -0.0076,  ..., -0.0243,  0.0043,  0.0222],
#         [-0.0167,  0.0220, -0.0781,  ..., -0.0080, -0.0158,  0.0004],
#         [ 0.0433, -0.0135,  0.0060,  ..., -0.0166, -0.0096,  0.0243]],
#        requires_grad=True)
# encoder.layer.21.output.dense.bias Parameter containing:
# tensor([-0.0271, -0.0457, -0.0261,  ...,  0.0573,  0.0206,  0.0371],
#        requires_grad=True)
# encoder.layer.21.output.LayerNorm.weight Parameter containing:
# tensor([0.9007, 0.9155, 0.9140,  ..., 0.9235, 0.9144, 0.9173],
#        requires_grad=True)
# encoder.layer.21.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0365,  0.0492,  0.0287,  ..., -0.0132,  0.0218,  0.0144],
#        requires_grad=True)
# encoder.layer.22.attention.self.query.weight Parameter containing:
# tensor([[-0.0282, -0.0173,  0.0468,  ..., -0.0070, -0.0072, -0.0011],
#         [ 0.0115, -0.0500,  0.0150,  ...,  0.0168, -0.0108,  0.0207],
#         [ 0.0202,  0.0609, -0.0256,  ..., -0.0621,  0.0041, -0.0284],
#         ...,
#         [ 0.0240, -0.0031, -0.0447,  ...,  0.0021, -0.0337,  0.0499],
#         [ 0.0475,  0.0406,  0.0208,  ..., -0.0692, -0.0571,  0.0082],
#         [-0.0780,  0.0522,  0.0106,  ..., -0.0173,  0.0255, -0.0836]],
#        requires_grad=True)
# encoder.layer.22.attention.self.query.bias Parameter containing:
# tensor([ 0.1501, -0.0991,  0.0510,  ...,  0.0147,  0.1117, -0.1311],
#        requires_grad=True)
# encoder.layer.22.attention.self.key.weight Parameter containing:
# tensor([[ 0.0122,  0.0233,  0.0054,  ...,  0.0205, -0.0093,  0.0382],
#         [ 0.0489, -0.0082,  0.0188,  ..., -0.0040, -0.0188, -0.0261],
#         [ 0.0138, -0.0469,  0.0245,  ...,  0.0058, -0.0139, -0.0722],
#         ...,
#         [-0.0141, -0.0319, -0.0030,  ...,  0.0096, -0.0040,  0.0165],
#         [-0.0572,  0.1023, -0.0177,  ..., -0.0194, -0.0264,  0.0056],
#         [-0.0414, -0.0101,  0.0180,  ...,  0.0427, -0.0052,  0.0039]],
#        requires_grad=True)
# encoder.layer.22.attention.self.key.bias Parameter containing:
# tensor([-0.0007, -0.0011,  0.0004,  ...,  0.0041,  0.0037,  0.0022],
#        requires_grad=True)
# encoder.layer.22.attention.self.value.weight Parameter containing:
# tensor([[ 0.0024, -0.0674, -0.0426,  ..., -0.0331,  0.0480, -0.0319],
#         [-0.0365, -0.0665, -0.0111,  ...,  0.0152, -0.0138,  0.0485],
#         [ 0.0606, -0.0028,  0.0283,  ...,  0.0153,  0.0407, -0.0256],
#         ...,
#         [-0.0223, -0.0380,  0.0223,  ..., -0.0022, -0.0055,  0.0011],
#         [ 0.0063,  0.0175,  0.0184,  ..., -0.0018,  0.0099, -0.0059],
#         [-0.0414, -0.0115, -0.0073,  ..., -0.0264, -0.0221,  0.0370]],
#        requires_grad=True)
# encoder.layer.22.attention.self.value.bias Parameter containing:
# tensor([-0.0119,  0.0088, -0.0041,  ..., -0.0143, -0.0169, -0.0049],
#        requires_grad=True)
# encoder.layer.22.attention.output.dense.weight Parameter containing:
# tensor([[ 0.0041,  0.0027,  0.0088,  ..., -0.0337, -0.0332,  0.0278],
#         [ 0.0243, -0.0036, -0.0220,  ...,  0.0024, -0.0021,  0.0015],
#         [ 0.0293, -0.0628, -0.0367,  ..., -0.0028,  0.0151, -0.0048],
#         ...,
#         [ 0.0015,  0.0404, -0.0229,  ..., -0.0219,  0.0022, -0.0042],
#         [-0.0955, -0.0381, -0.0020,  ..., -0.0220,  0.0289, -0.0029],
#         [-0.0575, -0.0001, -0.0261,  ..., -0.0021,  0.0447,  0.0161]],
#        requires_grad=True)
# encoder.layer.22.attention.output.dense.bias Parameter containing:
# tensor([-0.0019,  0.0094, -0.0132,  ..., -0.0102,  0.0068, -0.0059],
#        requires_grad=True)
# encoder.layer.22.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.8478, 0.8185, 0.8293,  ..., 0.8070, 0.8412, 0.8095],
#        requires_grad=True)
# encoder.layer.22.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0195, -0.0054,  0.0196,  ...,  0.0725,  0.0300,  0.0910],
#        requires_grad=True)
# encoder.layer.22.intermediate.dense.weight Parameter containing:
# tensor([[-0.0526, -0.0601, -0.0256,  ...,  0.0006,  0.0257,  0.0194],
#         [-0.0601, -0.0404, -0.0369,  ...,  0.0411, -0.0126, -0.0385],
#         [ 0.0195, -0.0211, -0.0011,  ..., -0.0092,  0.0291, -0.0077],
#         ...,
#         [ 0.0195,  0.0279, -0.0137,  ..., -0.0054,  0.0010,  0.0355],
#         [-0.0156, -0.0058, -0.0318,  ...,  0.0147, -0.0180,  0.0280],
#         [-0.0565, -0.0211,  0.0234,  ..., -0.0381, -0.0043, -0.0101]],
#        requires_grad=True)
# encoder.layer.22.intermediate.dense.bias Parameter containing:
# tensor([-0.0293, -0.0752, -0.0568,  ..., -0.0625, -0.0641, -0.0486],
#        requires_grad=True)
# encoder.layer.22.output.dense.weight Parameter containing:
# tensor([[-0.0245, -0.0065, -0.0775,  ..., -0.0272, -0.0039,  0.0418],
#         [-0.0255,  0.0016, -0.0200,  ...,  0.0119,  0.0197,  0.0495],
#         [ 0.0230,  0.0072, -0.0197,  ...,  0.0221, -0.0273, -0.0062],
#         ...,
#         [-0.0018, -0.0323,  0.0260,  ..., -0.0350,  0.0087,  0.0465],
#         [ 0.0126, -0.0542, -0.0474,  ..., -0.0108,  0.0173,  0.0145],
#         [-0.0081,  0.0332, -0.0109,  ..., -0.0323,  0.0194,  0.0384]],
#        requires_grad=True)
# encoder.layer.22.output.dense.bias Parameter containing:
# tensor([-0.0283, -0.0255, -0.0323,  ...,  0.0533, -0.0031,  0.0142],
#        requires_grad=True)
# encoder.layer.22.output.LayerNorm.weight Parameter containing:
# tensor([0.9302, 0.9363, 0.9304,  ..., 0.9359, 0.9303, 0.9161],
#        requires_grad=True)
# encoder.layer.22.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0223,  0.0434,  0.0181,  ...,  0.0011,  0.0065, -0.0151],
#        requires_grad=True)
# encoder.layer.23.attention.self.query.weight Parameter containing:
# tensor([[ 0.0032,  0.0387,  0.0035,  ...,  0.0411,  0.0041, -0.0036],
#         [ 0.0522,  0.0847,  0.0199,  ..., -0.0391,  0.0068, -0.0533],
#         [-0.0102, -0.0414,  0.0207,  ...,  0.0152,  0.0102,  0.0198],
#         ...,
#         [ 0.0786,  0.0222, -0.0259,  ...,  0.0656,  0.0014,  0.0277],
#         [-0.0409, -0.0250,  0.0571,  ...,  0.0283,  0.0322,  0.0689],
#         [ 0.0138, -0.0111,  0.0144,  ...,  0.0543, -0.0150, -0.0009]],
#        requires_grad=True)
# encoder.layer.23.attention.self.query.bias Parameter containing:
# tensor([-0.0960,  0.0029,  0.0376,  ...,  0.1438, -0.0946, -0.2944],
#        requires_grad=True)
# encoder.layer.23.attention.self.key.weight Parameter containing:
# tensor([[-0.0913, -0.0524, -0.0075,  ...,  0.0654,  0.0551,  0.0159],
#         [ 0.0289,  0.0226, -0.0670,  ...,  0.0181,  0.0113, -0.0522],
#         [ 0.0200, -0.0584,  0.0381,  ..., -0.0070,  0.0331,  0.0332],
#         ...,
#         [-0.0074,  0.0464,  0.0360,  ...,  0.0723,  0.0626,  0.0242],
#         [ 0.0444, -0.0327,  0.0539,  ..., -0.0576,  0.0024, -0.0414],
#         [-0.0408, -0.0829, -0.0173,  ..., -0.0260,  0.0043, -0.0394]],
#        requires_grad=True)
# encoder.layer.23.attention.self.key.bias Parameter containing:
# tensor([ 0.0018, -0.0016, -0.0028,  ..., -0.0009, -0.0010, -0.0032],
#        requires_grad=True)
# encoder.layer.23.attention.self.value.weight Parameter containing:
# tensor([[ 0.0495,  0.0120,  0.0117,  ...,  0.0270,  0.0156, -0.0464],
#         [-0.0140,  0.0047,  0.0324,  ...,  0.0133,  0.0601, -0.0438],
#         [ 0.0120, -0.0263,  0.0323,  ..., -0.0069,  0.0323,  0.0182],
#         ...,
#         [-0.0091,  0.0379,  0.0433,  ..., -0.0341,  0.0374, -0.0422],
#         [ 0.0181, -0.0231, -0.0688,  ..., -0.0468,  0.0138, -0.0530],
#         [-0.0161, -0.0354, -0.0272,  ..., -0.0170,  0.0327,  0.0134]],
#        requires_grad=True)
# encoder.layer.23.attention.self.value.bias Parameter containing:
# tensor([-0.0020,  0.0149,  0.0009,  ...,  0.0098, -0.0002, -0.0055],
#        requires_grad=True)
# encoder.layer.23.attention.output.dense.weight Parameter containing:
# tensor([[ 0.0284,  0.0528,  0.0009,  ...,  0.0186, -0.0131, -0.0004],
#         [ 0.0135,  0.0386,  0.0040,  ..., -0.0567,  0.0690,  0.0250],
#         [-0.0145, -0.0147,  0.0295,  ...,  0.0359,  0.0060, -0.0128],
#         ...,
#         [ 0.0675, -0.0103,  0.0222,  ..., -0.0205,  0.0362,  0.0212],
#         [ 0.0038,  0.0331,  0.0204,  ..., -0.0109,  0.0765, -0.0332],
#         [-0.0442, -0.0364, -0.0189,  ...,  0.0282,  0.0168, -0.0194]],
#        requires_grad=True)
# encoder.layer.23.attention.output.dense.bias Parameter containing:
# tensor([-0.0008,  0.0046,  0.0017,  ...,  0.0082,  0.0013, -0.0125],
#        requires_grad=True)
# encoder.layer.23.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.8541, 0.8285, 0.8417,  ..., 0.8122, 0.8599, 0.8210],
#        requires_grad=True)
# encoder.layer.23.attention.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0152,  0.0184,  0.0294,  ..., -0.0048, -0.0135,  0.0127],
#        requires_grad=True)
# encoder.layer.23.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0143, -0.0020, -0.0096,  ..., -0.0190,  0.0411, -0.0354],
#         [-0.0790,  0.0497,  0.0186,  ..., -0.0406,  0.0197,  0.0786],
#         [-0.0251, -0.0161, -0.0535,  ..., -0.0125,  0.0073,  0.0147],
#         ...,
#         [-0.0103, -0.0388, -0.0029,  ..., -0.0095, -0.0307,  0.0054],
#         [ 0.0045,  0.0457, -0.0304,  ..., -0.0104, -0.0169, -0.0103],
#         [ 0.0562, -0.0010, -0.0154,  ..., -0.0186, -0.0100, -0.0146]],
#        requires_grad=True)
# encoder.layer.23.intermediate.dense.bias Parameter containing:
# tensor([-0.0523, -0.0639, -0.0551,  ..., -0.0675, -0.0807, -0.0293],
#        requires_grad=True)
# encoder.layer.23.output.dense.weight Parameter containing:
# tensor([[-0.0404, -0.0155,  0.0406,  ..., -0.0199,  0.0253, -0.0368],
#         [ 0.0703,  0.0240,  0.0815,  ..., -0.0132, -0.0133,  0.0278],
#         [-0.0427,  0.0081, -0.0329,  ..., -0.0201, -0.0155, -0.0443],
#         ...,
#         [ 0.0109, -0.0115, -0.0308,  ..., -0.0022, -0.0333, -0.0335],
#         [-0.0183,  0.0017, -0.0268,  ...,  0.0156, -0.0166,  0.0125],
#         [ 0.0564, -0.0147, -0.0697,  ...,  0.0514,  0.0064, -0.0197]],
#        requires_grad=True)
# encoder.layer.23.output.dense.bias Parameter containing:
# tensor([ 0.0118, -0.0063, -0.0245,  ..., -0.0057, -0.0266,  0.0056],
#        requires_grad=True)
# encoder.layer.23.output.LayerNorm.weight Parameter containing:
# tensor([0.7078, 0.7500, 0.7275,  ..., 0.7114, 0.7231, 0.6928],
#        requires_grad=True)
# encoder.layer.23.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0547,  0.0670,  0.0421,  ..., -0.0172, -0.0762, -0.0607],
#        requires_grad=True)
# pooler.dense.weight Parameter containing:
# tensor([[-0.0391,  0.0444, -0.0249,  ...,  0.0010,  0.0244,  0.0079],
#         [-0.0225,  0.0373, -0.0350,  ..., -0.0122,  0.0424,  0.0095],
#         [-0.0328, -0.0122, -0.0519,  ..., -0.0761,  0.0065, -0.0129],
#         ...,
#         [-0.0033,  0.0137,  0.0128,  ...,  0.0554, -0.0628, -0.0112],
#         [-0.0333,  0.0165, -0.0234,  ..., -0.0384, -0.0343, -0.0629],
#         [ 0.0137,  0.0049, -0.0149,  ...,  0.0111,  0.0091,  0.0217]],
#        requires_grad=True)
# pooler.dense.bias Parameter containing:
# tensor([-0.0365, -0.0285,  0.0037,  ...,  0.0227,  0.0211, -0.0185],
#        requires_grad=True)

# %%
tl_strategy = 3

if tl_strategy == 1:
  for name, param in model.bert.named_parameters():
    param.requires_grad = False

elif tl_strategy == 2:
  for name, param in model.bert.named_parameters():
    if not name.startswith('pooler'):
      param.requires_grad = False

elif tl_strategy == 3:
  for name, param in model.bert.named_parameters():
    if ( not name.startswith('pooler') ) and "layer.23" not in name :
      param.requires_grad = False

# %%
for name, param in model.bert.named_parameters():
  print(name, param)
# Out:
# embeddings.word_embeddings.weight Parameter containing:
# tensor([[-0.0419,  0.0022, -0.0314,  ..., -0.0146, -0.0358, -0.0929],
#         [-0.0434, -0.0115, -0.0065,  ..., -0.0273, -0.0310, -0.1084],
#         [-0.0622, -0.0114, -0.0073,  ..., -0.0247, -0.0334, -0.0915],
#         ...,
#         [ 0.0239, -0.0083, -0.0061,  ...,  0.0176,  0.0214, -0.0763],
#         [-0.0468, -0.0018,  0.0020,  ..., -0.0173, -0.0243, -0.1124],
#         [-0.0185, -0.0369, -0.0623,  ..., -0.0054, -0.0412, -0.0847]])
# embeddings.position_embeddings.weight Parameter containing:
# tensor([[ 0.0041, -0.0139, -0.0263,  ..., -0.0042, -0.0212,  0.0148],
#         [ 0.0097,  0.0067, -0.0287,  ...,  0.0003,  0.0051,  0.0049],
#         [ 0.0005, -0.0129, -0.0019,  ..., -0.0006,  0.0247,  0.0181],
#         ...,
#         [ 0.0047,  0.0026,  0.0021,  ...,  0.0092, -0.0113,  0.0185],
#         [-0.0161, -0.0068,  0.0181,  ...,  0.0040, -0.0194,  0.0058],
#         [ 0.0218,  0.0243,  0.0312,  ...,  0.0091,  0.0013,  0.0184]])
# embeddings.token_type_embeddings.weight Parameter containing:
# tensor([[-0.0027, -0.0044,  0.0125,  ..., -0.0058,  0.0047, -0.0005],
#         [ 0.0047, -0.0022, -0.0008,  ..., -0.0091, -0.0024,  0.0115]])
# embeddings.LayerNorm.weight Parameter containing:
# tensor([0.8801, 0.8972, 0.8730,  ..., 0.9364, 0.9117, 0.8275])
# embeddings.LayerNorm.bias Parameter containing:
# tensor([-0.0303, -0.0041, -0.0374,  ...,  0.0183, -0.0110,  0.0441])
# encoder.layer.0.attention.self.query.weight Parameter containing:
# tensor([[ 0.0167, -0.0422, -0.0425,  ...,  0.0302, -0.0341,  0.0251],
#         [ 0.0323,  0.0347, -0.0041,  ..., -0.0722,  0.0031, -0.0351],
#         [ 0.0387, -0.0293, -0.0694,  ...,  0.0492,  0.0201, -0.0727],
#         ...,
#         [ 0.0035,  0.0081, -0.0337,  ...,  0.0460,  0.0268,  0.0747],
#         [ 0.0513,  0.0131,  0.0735,  ..., -0.0127,  0.0144, -0.0400],
#         [ 0.0385,  0.0013, -0.0272,  ...,  0.0148,  0.0399,  0.0339]])
# encoder.layer.0.attention.self.query.bias Parameter containing:
# tensor([ 0.0087,  0.1857, -0.0485,  ..., -0.2867, -0.1432,  0.1627])
# encoder.layer.0.attention.self.key.weight Parameter containing:
# tensor([[-0.0571,  0.0281, -0.0172,  ..., -0.0023,  0.0284,  0.0498],
#         [-0.0449,  0.0399, -0.0205,  ..., -0.0576,  0.0355,  0.0228],
#         [ 0.0182,  0.0311,  0.0593,  ...,  0.0873,  0.0816, -0.0162],
#         ...,
#         [-0.0109,  0.0104, -0.0188,  ..., -0.0390,  0.0144,  0.0371],
#         [-0.0016,  0.0229,  0.0056,  ...,  0.0203, -0.0179,  0.0431],
#         [ 0.0034, -0.0112, -0.0204,  ...,  0.0052,  0.0094, -0.0235]])
# encoder.layer.0.attention.self.key.bias Parameter containing:
# tensor([-0.0031,  0.0022,  0.0020,  ...,  0.0007, -0.0002,  0.0002])
# encoder.layer.0.attention.self.value.weight Parameter containing:
# tensor([[-0.0043, -0.0113,  0.0281,  ...,  0.0033, -0.0223,  0.0054],
#         [-0.0352, -0.0200, -0.0177,  ...,  0.0310,  0.0244,  0.0285],
#         [-0.0037, -0.0024, -0.0635,  ..., -0.0428,  0.0309,  0.0052],
#         ...,
#         [ 0.0302, -0.0310,  0.0043,  ...,  0.0175,  0.0145, -0.0235],
#         [-0.0345, -0.0232, -0.0001,  ..., -0.0307, -0.0095,  0.0285],
#         [-0.0143, -0.0174, -0.0008,  ...,  0.0094,  0.0043, -0.0017]])
# encoder.layer.0.attention.self.value.bias Parameter containing:
# tensor([-0.0010,  0.0183, -0.0122,  ..., -0.0048,  0.0014, -0.0202])
# encoder.layer.0.attention.output.dense.weight Parameter containing:
# tensor([[ 0.0012,  0.0084, -0.0162,  ...,  0.0123, -0.0039, -0.0098],
#         [ 0.0059, -0.0185,  0.0313,  ..., -0.0329, -0.0133, -0.0247],
#         [ 0.0168, -0.0150, -0.0164,  ...,  0.0332,  0.0079, -0.0137],
#         ...,
#         [-0.0527, -0.0152, -0.0410,  ...,  0.0290, -0.0049, -0.0136],
#         [-0.0076,  0.0398,  0.0136,  ..., -0.0018,  0.0228,  0.0154],
#         [-0.0385,  0.0236,  0.0116,  ..., -0.0212, -0.0008, -0.0085]])
# encoder.layer.0.attention.output.dense.bias Parameter containing:
# tensor([-0.0259,  0.0296,  0.0099,  ..., -0.0157,  0.0172,  0.0048])
# encoder.layer.0.attention.output.LayerNorm.weight Parameter containing:
# tensor([1.0223, 1.0159, 1.0278,  ..., 1.0545, 1.0441, 1.0321])
# encoder.layer.0.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0568,  0.0686,  0.2091,  ..., -0.3218,  0.2872, -0.0747])
# encoder.layer.0.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0573, -0.0164,  0.0500,  ...,  0.0499,  0.0380,  0.0136],
#         [ 0.0254,  0.0115,  0.0222,  ...,  0.0491, -0.0255,  0.0345],
#         [-0.0262,  0.0537,  0.0151,  ...,  0.0100, -0.0887, -0.0037],
#         ...,
#         [ 0.0100,  0.0010, -0.0044,  ...,  0.0413, -0.0270, -0.0023],
#         [ 0.0341,  0.0658, -0.0308,  ...,  0.0110,  0.0557,  0.0961],
#         [-0.0437,  0.0143,  0.0067,  ...,  0.0104, -0.0125, -0.0128]])
# encoder.layer.0.intermediate.dense.bias Parameter containing:
# tensor([-0.1383, -0.0872, -0.0970,  ..., -0.0788, -0.0744, -0.0539])
# encoder.layer.0.output.dense.weight Parameter containing:
# tensor([[ 0.0366,  0.0135,  0.0492,  ..., -0.0274,  0.0493,  0.0242],
#         [-0.0113,  0.0504,  0.0469,  ..., -0.0269, -0.0224, -0.0305],
#         [ 0.0192, -0.0152,  0.0119,  ...,  0.0115, -0.0182, -0.0063],
#         ...,
#         [-0.0370, -0.0460,  0.0203,  ...,  0.0157, -0.0529,  0.0139],
#         [-0.0523, -0.0192, -0.0612,  ..., -0.0515,  0.0169,  0.0098],
#         [ 0.0277, -0.0029, -0.0349,  ...,  0.0014, -0.0453,  0.0052]])
# encoder.layer.0.output.dense.bias Parameter containing:
# tensor([ 0.0196,  0.0067, -0.0165,  ...,  0.0177, -0.0003,  0.0366])
# encoder.layer.0.output.LayerNorm.weight Parameter containing:
# tensor([0.9134, 0.9069, 0.8905,  ..., 0.8861, 0.9277, 0.8856])
# encoder.layer.0.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0189,  0.0241, -0.0265,  ...,  0.1248, -0.0310,  0.0613])
# encoder.layer.1.attention.self.query.weight Parameter containing:
# tensor([[ 0.0377,  0.0077, -0.0352,  ..., -0.0110,  0.0054, -0.0216],
#         [ 0.0313, -0.0175,  0.0093,  ...,  0.0098, -0.0212,  0.0027],
#         [-0.0543,  0.0006,  0.0116,  ...,  0.0155, -0.0327,  0.0438],
#         ...,
#         [ 0.0019,  0.0546,  0.0053,  ...,  0.0192, -0.0125, -0.0138],
#         [-0.0074,  0.0109, -0.0073,  ...,  0.0143,  0.0169, -0.0136],
#         [-0.0171, -0.0679, -0.0456,  ..., -0.0463,  0.0099, -0.0421]])
# encoder.layer.1.attention.self.query.bias Parameter containing:
# tensor([-0.0349, -0.0187,  0.0331,  ..., -0.0264,  0.0608, -0.0007])
# encoder.layer.1.attention.self.key.weight Parameter containing:
# tensor([[-0.0039,  0.0144,  0.0084,  ..., -0.0016,  0.0073,  0.0269],
#         [-0.0529,  0.0067, -0.0182,  ..., -0.0240, -0.0141, -0.0149],
#         [-0.0241, -0.0103,  0.0622,  ..., -0.0216,  0.0089,  0.0323],
#         ...,
#         [-0.0240, -0.0493,  0.0061,  ...,  0.0075,  0.0239,  0.0659],
#         [ 0.0535,  0.0297,  0.0233,  ..., -0.0207,  0.0406, -0.0255],
#         [-0.0287,  0.0166, -0.0174,  ...,  0.0297, -0.0216,  0.0351]])
# encoder.layer.1.attention.self.key.bias Parameter containing:
# tensor([-0.0030, -0.0010,  0.0053,  ..., -0.0023, -0.0006,  0.0007])
# encoder.layer.1.attention.self.value.weight Parameter containing:
# tensor([[-0.0182,  0.0008,  0.0225,  ...,  0.0276, -0.0075,  0.0740],
#         [ 0.0285, -0.0466, -0.0197,  ..., -0.0116, -0.0393, -0.0102],
#         [-0.0044,  0.0135,  0.0176,  ...,  0.0315,  0.0351,  0.0167],
#         ...,
#         [-0.0014, -0.0125, -0.0001,  ..., -0.0031, -0.0457,  0.0144],
#         [-0.0393, -0.0026, -0.0124,  ..., -0.0123, -0.0186, -0.0095],
#         [ 0.0033,  0.0217,  0.0066,  ..., -0.0225,  0.0186, -0.0115]])
# encoder.layer.1.attention.self.value.bias Parameter containing:
# tensor([-0.0038, -0.0166, -0.0119,  ..., -0.0076, -0.0018,  0.0045])
# encoder.layer.1.attention.output.dense.weight Parameter containing:
# tensor([[-0.0167, -0.0028,  0.0273,  ...,  0.0291,  0.0377, -0.0008],
#         [ 0.0046, -0.0383, -0.0025,  ..., -0.0069, -0.0010, -0.0107],
#         [ 0.0418,  0.0105,  0.0085,  ..., -0.0111,  0.0034, -0.0246],
#         ...,
#         [ 0.0021,  0.0049, -0.0293,  ...,  0.0178,  0.0187,  0.0154],
#         [-0.0111,  0.0084,  0.0020,  ...,  0.0466,  0.0003, -0.0162],
#         [ 0.0303,  0.0377,  0.0008,  ..., -0.0098,  0.0070,  0.0303]])
# encoder.layer.1.attention.output.dense.bias Parameter containing:
# tensor([ 0.0091,  0.0031, -0.0063,  ..., -0.0180,  0.0236,  0.0213])
# encoder.layer.1.attention.output.LayerNorm.weight Parameter containing:
# tensor([1.0149, 0.9907, 1.0102,  ..., 1.0224, 1.0286, 1.0217])
# encoder.layer.1.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0973,  0.1046,  0.0980,  ..., -0.1860,  0.1964, -0.0124])
# encoder.layer.1.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0242,  0.0313,  0.0073,  ...,  0.0282, -0.0085, -0.0142],
#         [ 0.0252,  0.0128, -0.0882,  ...,  0.0530, -0.0882, -0.0490],
#         [-0.0728, -0.0252, -0.0248,  ...,  0.0063, -0.0259, -0.0317],
#         ...,
#         [ 0.0684, -0.0231, -0.0270,  ..., -0.0062, -0.0221, -0.0348],
#         [-0.0132, -0.0320,  0.0564,  ..., -0.0240, -0.0383, -0.0201],
#         [ 0.0258, -0.0265, -0.0393,  ..., -0.0712, -0.0152, -0.0365]])
# encoder.layer.1.intermediate.dense.bias Parameter containing:
# tensor([-0.0646, -0.0781, -0.0466,  ..., -0.0526, -0.0698, -0.0622])
# encoder.layer.1.output.dense.weight Parameter containing:
# tensor([[-0.0043,  0.0077, -0.0470,  ...,  0.0370, -0.0171,  0.0405],
#         [-0.0021, -0.0078,  0.0070,  ..., -0.0386,  0.0198,  0.0137],
#         [-0.0244, -0.0163, -0.0239,  ...,  0.0011,  0.0027,  0.0912],
#         ...,
#         [ 0.0524,  0.0020, -0.0486,  ...,  0.0069, -0.0152, -0.0111],
#         [ 0.0316, -0.0059,  0.0128,  ..., -0.0126,  0.0073,  0.0388],
#         [-0.0085,  0.0165, -0.0253,  ...,  0.0124,  0.0319,  0.0150]])
# encoder.layer.1.output.dense.bias Parameter containing:
# tensor([-0.0074,  0.0161, -0.0435,  ...,  0.0413, -0.0100,  0.0013])
# encoder.layer.1.output.LayerNorm.weight Parameter containing:
# tensor([0.9435, 0.9484, 0.9432,  ..., 0.9351, 0.9598, 0.9404])
# encoder.layer.1.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0792, -0.0241,  0.0017,  ...,  0.1076, -0.0704,  0.0217])
# encoder.layer.2.attention.self.query.weight Parameter containing:
# tensor([[ 0.0080, -0.0390, -0.0392,  ...,  0.0480,  0.0586,  0.0723],
#         [ 0.0424,  0.0570,  0.0172,  ...,  0.0436,  0.0100, -0.0178],
#         [-0.0874, -0.0358,  0.0498,  ...,  0.0166,  0.0108, -0.0458],
#         ...,
#         [ 0.0121, -0.0075,  0.0065,  ...,  0.0683,  0.0129, -0.1068],
#         [ 0.0051, -0.0203, -0.0063,  ..., -0.0145, -0.0548, -0.0127],
#         [ 0.0368,  0.0310, -0.0037,  ..., -0.0352, -0.0483,  0.0392]])
# encoder.layer.2.attention.self.query.bias Parameter containing:
# tensor([ 0.0005,  0.0655, -0.0002,  ..., -0.0587, -0.0060, -0.0238])
# encoder.layer.2.attention.self.key.weight Parameter containing:
# tensor([[-0.0436,  0.0257, -0.0348,  ..., -0.0176, -0.0151, -0.0086],
#         [-0.0490, -0.0144,  0.0353,  ..., -0.0330, -0.0081, -0.0097],
#         [ 0.0142,  0.0350, -0.0127,  ...,  0.0318, -0.0912, -0.0357],
#         ...,
#         [ 0.0034,  0.0612, -0.0198,  ...,  0.0099, -0.0266,  0.0329],
#         [ 0.0466,  0.0258,  0.0004,  ...,  0.0222, -0.0057,  0.0086],
#         [-0.0145, -0.0014,  0.0027,  ...,  0.0439, -0.0421,  0.0754]])
# encoder.layer.2.attention.self.key.bias Parameter containing:
# tensor([-0.0030,  0.0004, -0.0094,  ..., -0.0003, -0.0009, -0.0001])
# encoder.layer.2.attention.self.value.weight Parameter containing:
# tensor([[-0.0335,  0.0321, -0.0119,  ..., -0.0014, -0.0063, -0.0563],
#         [-0.0209,  0.0132, -0.0466,  ..., -0.0033,  0.0105,  0.0029],
#         [-0.0088, -0.0170, -0.0282,  ..., -0.0400, -0.0137, -0.0091],
#         ...,
#         [-0.0050,  0.0255, -0.0111,  ...,  0.0432,  0.0253, -0.0074],
#         [-0.0065, -0.0415,  0.0081,  ...,  0.0129, -0.0275, -0.0357],
#         [-0.0152,  0.0019,  0.0302,  ..., -0.0293,  0.0243,  0.0010]])
# encoder.layer.2.attention.self.value.bias Parameter containing:
# tensor([ 0.0054, -0.0777, -0.0119,  ...,  0.0221,  0.0032,  0.0010])
# encoder.layer.2.attention.output.dense.weight Parameter containing:
# tensor([[-0.0600,  0.0451, -0.0082,  ...,  0.0118, -0.0080,  0.0354],
#         [-0.0193, -0.0188,  0.0099,  ..., -0.0161,  0.0012, -0.0056],
#         [-0.0131,  0.0420, -0.0509,  ...,  0.0403, -0.0002,  0.0091],
#         ...,
#         [-0.0296, -0.0072, -0.0017,  ..., -0.0252,  0.0039, -0.0147],
#         [ 0.0296,  0.0229, -0.0021,  ..., -0.0425,  0.0095, -0.0127],
#         [-0.0201, -0.0074, -0.0427,  ..., -0.0115,  0.0266,  0.0105]])
# encoder.layer.2.attention.output.dense.bias Parameter containing:
# tensor([ 0.0193, -0.0342,  0.0175,  ..., -0.0143, -0.0067,  0.0397])
# encoder.layer.2.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.9922, 0.9859, 1.0080,  ..., 1.0007, 0.9944, 0.9829])
# encoder.layer.2.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0745,  0.0468,  0.1724,  ..., -0.1062,  0.1043, -0.0145])
# encoder.layer.2.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0135,  0.0602, -0.0610,  ...,  0.0111, -0.0125,  0.0404],
#         [-0.0012, -0.0622, -0.0593,  ..., -0.0352, -0.0347,  0.0217],
#         [ 0.0069, -0.0212, -0.0166,  ...,  0.0384,  0.0119,  0.0531],
#         ...,
#         [-0.0496,  0.0621, -0.0284,  ...,  0.0047,  0.0125,  0.0200],
#         [ 0.0214, -0.0140, -0.0038,  ..., -0.0240,  0.0365, -0.0558],
#         [-0.0536,  0.0357, -0.0020,  ..., -0.0257,  0.0614,  0.0351]])
# encoder.layer.2.intermediate.dense.bias Parameter containing:
# tensor([-0.0628, -0.0646, -0.0439,  ..., -0.0353, -0.0722, -0.0549])
# encoder.layer.2.output.dense.weight Parameter containing:
# tensor([[-0.0218,  0.0245,  0.0065,  ..., -0.0311,  0.0022,  0.0078],
#         [ 0.0139,  0.0062,  0.0507,  ...,  0.0215, -0.0290,  0.0189],
#         [-0.0405,  0.0629, -0.0171,  ..., -0.0286,  0.0296,  0.0316],
#         ...,
#         [ 0.0303, -0.0372,  0.0222,  ...,  0.0150, -0.0312,  0.0283],
#         [ 0.0382,  0.0227,  0.0151,  ...,  0.0508,  0.0116,  0.0244],
#         [ 0.0046, -0.0326,  0.0502,  ...,  0.0186, -0.0525,  0.0143]])
# encoder.layer.2.output.dense.bias Parameter containing:
# tensor([ 0.0038,  0.0072, -0.0306,  ...,  0.0568, -0.0237,  0.0038])
# encoder.layer.2.output.LayerNorm.weight Parameter containing:
# tensor([0.9300, 0.9419, 0.9198,  ..., 0.9347, 0.9537, 0.9175])
# encoder.layer.2.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0681, -0.0042, -0.0613,  ...,  0.1118, -0.0474,  0.0479])
# encoder.layer.3.attention.self.query.weight Parameter containing:
# tensor([[-0.0601,  0.0315, -0.0367,  ...,  0.0554,  0.0622, -0.0079],
#         [ 0.0126, -0.0642,  0.0141,  ...,  0.0257, -0.0571, -0.0080],
#         [ 0.0019,  0.0149, -0.0028,  ...,  0.0326,  0.0008,  0.0220],
#         ...,
#         [-0.0189,  0.0309,  0.0218,  ...,  0.0393, -0.0069, -0.0086],
#         [-0.0691, -0.0036,  0.0067,  ...,  0.0435,  0.0450,  0.0668],
#         [-0.0102, -0.0385,  0.0383,  ...,  0.0838,  0.0456, -0.0303]])
# encoder.layer.3.attention.self.query.bias Parameter containing:
# tensor([-0.0226,  0.0160, -0.0183,  ..., -0.0556,  0.0249, -0.0446])
# encoder.layer.3.attention.self.key.weight Parameter containing:
# tensor([[-0.0587, -0.0343,  0.0386,  ..., -0.0288, -0.0430, -0.0296],
#         [-0.0226,  0.0484,  0.0192,  ..., -0.0042,  0.0258,  0.0544],
#         [-0.0216, -0.0238, -0.0302,  ..., -0.0660,  0.0448,  0.0411],
#         ...,
#         [ 0.0048,  0.0376,  0.0246,  ..., -0.0517,  0.0318,  0.0036],
#         [ 0.0095,  0.0163,  0.0177,  ..., -0.0234, -0.0278, -0.0328],
#         [-0.0305, -0.0033,  0.0027,  ...,  0.0014, -0.0305, -0.0233]])
# encoder.layer.3.attention.self.key.bias Parameter containing:
# tensor([ 0.0008, -0.0018, -0.0006,  ..., -0.0008, -0.0009, -0.0010])
# encoder.layer.3.attention.self.value.weight Parameter containing:
# tensor([[-0.0028,  0.0181, -0.0059,  ...,  0.0766, -0.0135, -0.0571],
#         [ 0.0190, -0.0012,  0.0088,  ...,  0.0226, -0.0309, -0.0157],
#         [ 0.0069,  0.0205,  0.0202,  ...,  0.0307, -0.0725, -0.0190],
#         ...,
#         [ 0.0152, -0.0215,  0.0271,  ...,  0.0106, -0.0125, -0.0018],
#         [-0.0406, -0.0279, -0.0256,  ..., -0.0036, -0.0349,  0.0032],
#         [ 0.0163, -0.0053, -0.0167,  ..., -0.0181, -0.0171,  0.0383]])
# encoder.layer.3.attention.self.value.bias Parameter containing:
# tensor([ 0.0046, -0.0146, -0.0185,  ...,  0.0163, -0.0135, -0.0162])
# encoder.layer.3.attention.output.dense.weight Parameter containing:
# tensor([[ 0.0122, -0.0039,  0.0168,  ...,  0.0138,  0.0013, -0.0101],
#         [-0.0209,  0.0208, -0.0265,  ..., -0.0051,  0.0269, -0.0044],
#         [ 0.0033, -0.0194, -0.0089,  ..., -0.0003,  0.0226,  0.0015],
#         ...,
#         [-0.0207,  0.0033, -0.0212,  ...,  0.0087, -0.0025,  0.0063],
#         [-0.0275,  0.0194,  0.0329,  ..., -0.0172,  0.0335,  0.0086],
#         [ 0.0185,  0.0040,  0.0184,  ..., -0.0167,  0.0016,  0.0102]])
# encoder.layer.3.attention.output.dense.bias Parameter containing:
# tensor([-0.0198,  0.0680, -0.0337,  ...,  0.0489, -0.0094,  0.0011])
# encoder.layer.3.attention.output.LayerNorm.weight Parameter containing:
# tensor([1.0002, 0.9855, 1.0081,  ..., 0.9869, 0.9863, 0.9685])
# encoder.layer.3.attention.output.LayerNorm.bias Parameter containing:
# tensor([-1.3775e-01,  1.1437e-04,  1.9784e-01,  ..., -5.1143e-02,
#          5.0889e-02,  1.9371e-02])
# encoder.layer.3.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0661,  0.0230, -0.0260,  ..., -0.0155, -0.0764, -0.0195],
#         [-0.0131, -0.0811, -0.0069,  ...,  0.0039,  0.0327,  0.0755],
#         [-0.0022,  0.0036, -0.0714,  ...,  0.0273, -0.0434,  0.0318],
#         ...,
#         [ 0.0615,  0.0572, -0.0159,  ..., -0.0129, -0.0265,  0.0489],
#         [ 0.0072,  0.0521, -0.0216,  ..., -0.0349,  0.0060, -0.0048],
#         [ 0.0448, -0.0491, -0.0080,  ...,  0.0471,  0.0030,  0.0265]])
# encoder.layer.3.intermediate.dense.bias Parameter containing:
# tensor([-0.0705, -0.0635, -0.0625,  ..., -0.0614, -0.0653, -0.0579])
# encoder.layer.3.output.dense.weight Parameter containing:
# tensor([[-0.0512, -0.0199,  0.0281,  ...,  0.0752, -0.0044,  0.0117],
#         [-0.0226,  0.0350,  0.0155,  ...,  0.0204,  0.0092,  0.0332],
#         [ 0.0272, -0.0500, -0.0301,  ..., -0.0179, -0.0368,  0.0114],
#         ...,
#         [-0.0150,  0.0069,  0.0229,  ...,  0.0099, -0.0602,  0.0269],
#         [ 0.0211,  0.0304, -0.0175,  ..., -0.0572, -0.0144, -0.0237],
#         [-0.0279, -0.0206, -0.0495,  ..., -0.0278,  0.0102, -0.0294]])
# encoder.layer.3.output.dense.bias Parameter containing:
# tensor([-0.0046,  0.0263, -0.0540,  ...,  0.0728, -0.0265, -0.0161])
# encoder.layer.3.output.LayerNorm.weight Parameter containing:
# tensor([0.9145, 0.9362, 0.8880,  ..., 0.9212, 0.9546, 0.9023])
# encoder.layer.3.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0951,  0.0145, -0.0806,  ...,  0.1077, -0.0328,  0.0170])
# encoder.layer.4.attention.self.query.weight Parameter containing:
# tensor([[ 0.0530,  0.0253, -0.0425,  ..., -0.0031, -0.0173,  0.0009],
#         [ 0.0078, -0.0295,  0.0476,  ...,  0.0054,  0.0179, -0.0143],
#         [-0.0204,  0.0058, -0.0300,  ...,  0.0261, -0.0198, -0.0282],
#         ...,
#         [-0.0602,  0.0136,  0.0719,  ..., -0.0060,  0.0265, -0.0351],
#         [ 0.0134,  0.0230,  0.0537,  ...,  0.0125, -0.0040,  0.0259],
#         [ 0.0509, -0.0721,  0.0021,  ..., -0.0122, -0.0165,  0.0202]])
# encoder.layer.4.attention.self.query.bias Parameter containing:
# tensor([ 0.0241, -0.0355,  0.0524,  ..., -0.0120, -0.0075, -0.0178])
# encoder.layer.4.attention.self.key.weight Parameter containing:
# tensor([[-0.0608, -0.0087,  0.0294,  ..., -0.0335, -0.0069,  0.0079],
#         [-0.0103, -0.0190,  0.0180,  ..., -0.0310,  0.0395, -0.0228],
#         [ 0.0095,  0.0355, -0.0225,  ..., -0.0513, -0.0216, -0.0086],
#         ...,
#         [-0.0108, -0.0250, -0.0656,  ..., -0.0120,  0.0168, -0.0209],
#         [ 0.0131,  0.0013, -0.0340,  ...,  0.0546, -0.0262, -0.0383],
#         [ 0.0288,  0.0004,  0.0550,  ...,  0.0341,  0.0079, -0.0253]])
# encoder.layer.4.attention.self.key.bias Parameter containing:
# tensor([ 0.0033, -0.0024, -0.0048,  ...,  0.0006, -0.0022, -0.0015])
# encoder.layer.4.attention.self.value.weight Parameter containing:
# tensor([[-0.0064, -0.0043, -0.0105,  ..., -0.0128, -0.0053,  0.0382],
#         [ 0.0315,  0.0068, -0.0335,  ...,  0.0009, -0.0258, -0.0180],
#         [ 0.0067, -0.0300, -0.0026,  ..., -0.0014,  0.0311,  0.0042],
#         ...,
#         [-0.0027, -0.0255,  0.0222,  ..., -0.0334,  0.0372,  0.0377],
#         [ 0.0177, -0.0309, -0.0185,  ...,  0.0163,  0.0260,  0.0514],
#         [ 0.0541,  0.0411, -0.0113,  ...,  0.0149,  0.0464,  0.0200]])
# encoder.layer.4.attention.self.value.bias Parameter containing:
# tensor([ 0.0179,  0.0049, -0.0072,  ...,  0.0087,  0.0166,  0.0076])
# encoder.layer.4.attention.output.dense.weight Parameter containing:
# tensor([[-0.0118,  0.0030,  0.0027,  ..., -0.0005, -0.0188, -0.0200],
#         [ 0.0426, -0.0525, -0.0046,  ...,  0.0063,  0.0036,  0.0163],
#         [ 0.0049,  0.0056, -0.0184,  ..., -0.0022, -0.0355,  0.0203],
#         ...,
#         [ 0.0014,  0.0051,  0.0058,  ...,  0.0003, -0.0510, -0.0103],
#         [ 0.0433,  0.0130, -0.0071,  ..., -0.0029, -0.0097, -0.0122],
#         [-0.0344,  0.0033,  0.0187,  ..., -0.0442,  0.0155, -0.0162]])
# encoder.layer.4.attention.output.dense.bias Parameter containing:
# tensor([ 0.0204, -0.0005, -0.0127,  ...,  0.0041,  0.0086,  0.0316])
# encoder.layer.4.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.9762, 0.9503, 0.9849,  ..., 0.9656, 0.9678, 0.9498])
# encoder.layer.4.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.1244,  0.0591,  0.2191,  ...,  0.0481, -0.0330,  0.0582])
# encoder.layer.4.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0482,  0.0069,  0.0587,  ...,  0.0350,  0.0263,  0.0033],
#         [ 0.0152, -0.0267,  0.0015,  ..., -0.0402, -0.0116, -0.0191],
#         [-0.0368,  0.0439,  0.0114,  ..., -0.0181,  0.0170, -0.0074],
#         ...,
#         [-0.0109, -0.0160,  0.0616,  ..., -0.0268,  0.0283,  0.0077],
#         [-0.0250,  0.0177,  0.0118,  ...,  0.0178, -0.0553, -0.0151],
#         [ 0.0549, -0.0187, -0.0122,  ..., -0.0305, -0.0082,  0.0056]])
# encoder.layer.4.intermediate.dense.bias Parameter containing:
# tensor([-0.0541, -0.0682, -0.0310,  ..., -0.0501, -0.0513, -0.0410])
# encoder.layer.4.output.dense.weight Parameter containing:
# tensor([[-0.0353,  0.0157,  0.0063,  ..., -0.0536,  0.0280, -0.0262],
#         [-0.0274, -0.0558,  0.0018,  ..., -0.0570, -0.0176, -0.0011],
#         [-0.0313, -0.0128, -0.0156,  ..., -0.0206,  0.0583,  0.0625],
#         ...,
#         [ 0.0751,  0.0310, -0.0277,  ..., -0.0072, -0.0035, -0.0273],
#         [ 0.0031,  0.0256,  0.0207,  ..., -0.0271, -0.0137, -0.0100],
#         [ 0.0055, -0.0179,  0.0185,  ...,  0.0045, -0.0185, -0.0412]])
# encoder.layer.4.output.dense.bias Parameter containing:
# tensor([-0.0333,  0.0290, -0.0072,  ...,  0.0728, -0.0235, -0.0208])
# encoder.layer.4.output.LayerNorm.weight Parameter containing:
# tensor([0.9173, 0.9286, 0.8971,  ..., 0.9417, 0.9601, 0.9048])
# encoder.layer.4.output.LayerNorm.bias Parameter containing:
# tensor([ 0.1147, -0.0026, -0.0614,  ...,  0.0461,  0.0067,  0.0371])
# encoder.layer.5.attention.self.query.weight Parameter containing:
# tensor([[ 0.0183, -0.0205, -0.0345,  ..., -0.0013, -0.0203,  0.0330],
#         [ 0.0047, -0.0501,  0.0479,  ...,  0.0382, -0.0268, -0.0097],
#         [ 0.0048,  0.0450, -0.0008,  ..., -0.0224, -0.0002,  0.0783],
#         ...,
#         [ 0.0007,  0.0569, -0.0415,  ..., -0.0172, -0.0034,  0.0094],
#         [ 0.0328,  0.0158, -0.0550,  ...,  0.0038, -0.0220,  0.0103],
#         [-0.0212, -0.0271,  0.0289,  ...,  0.0157, -0.0383, -0.0436]])
# encoder.layer.5.attention.self.query.bias Parameter containing:
# tensor([-0.0450,  0.0212, -0.0414,  ..., -0.0359,  0.0057, -0.0394])
# encoder.layer.5.attention.self.key.weight Parameter containing:
# tensor([[ 0.0320, -0.0578, -0.0143,  ...,  0.0205,  0.0186,  0.0136],
#         [-0.0171, -0.0353,  0.0423,  ...,  0.0029,  0.0097,  0.0345],
#         [ 0.0181, -0.0078, -0.0272,  ...,  0.0233, -0.0217,  0.0379],
#         ...,
#         [-0.0425, -0.0374,  0.0257,  ...,  0.0105,  0.0272,  0.0024],
#         [ 0.0155,  0.0194,  0.0312,  ...,  0.0246,  0.0243,  0.0033],
#         [ 0.0090, -0.0100,  0.0103,  ...,  0.0154,  0.0214,  0.0429]])
# encoder.layer.5.attention.self.key.bias Parameter containing:
# tensor([-0.0004,  0.0005,  0.0006,  ..., -0.0046,  0.0070, -0.0073])
# encoder.layer.5.attention.self.value.weight Parameter containing:
# tensor([[ 0.0329, -0.0270,  0.0240,  ..., -0.0203,  0.0326,  0.0146],
#         [-0.0072, -0.0123, -0.0305,  ...,  0.0113, -0.0314,  0.0512],
#         [ 0.0327, -0.0276,  0.0199,  ..., -0.0044,  0.0058, -0.0037],
#         ...,
#         [-0.0354,  0.0004, -0.0134,  ..., -0.0325,  0.0195,  0.0136],
#         [-0.0818,  0.0013, -0.0037,  ...,  0.0002, -0.0345, -0.0010],
#         [-0.0251,  0.0503, -0.0232,  ...,  0.0165, -0.0021, -0.0038]])
# encoder.layer.5.attention.self.value.bias Parameter containing:
# tensor([-0.0081,  0.0049,  0.0094,  ..., -0.0048,  0.0041, -0.0148])
# encoder.layer.5.attention.output.dense.weight Parameter containing:
# tensor([[-0.0092,  0.0220, -0.0128,  ..., -0.0259, -0.0310,  0.0171],
#         [ 0.0383,  0.0119,  0.0542,  ...,  0.0320, -0.0033, -0.0124],
#         [ 0.0441, -0.0002, -0.0119,  ..., -0.0250,  0.0252, -0.0442],
#         ...,
#         [-0.0100,  0.0278, -0.0215,  ..., -0.0084,  0.0095, -0.0603],
#         [ 0.0427,  0.0013,  0.0131,  ..., -0.0093,  0.0055,  0.0226],
#         [-0.0433,  0.0068, -0.0016,  ...,  0.0462,  0.0276, -0.0145]])
# encoder.layer.5.attention.output.dense.bias Parameter containing:
# tensor([-0.0153,  0.0147,  0.0063,  ...,  0.0168, -0.0151,  0.0056])
# encoder.layer.5.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.9539, 0.9351, 0.9821,  ..., 0.9435, 0.9573, 0.9292])
# encoder.layer.5.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.1253,  0.0572,  0.2918,  ...,  0.0628, -0.1274,  0.1278])
# encoder.layer.5.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0281,  0.0170, -0.0311,  ..., -0.0490, -0.0038, -0.0092],
#         [ 0.0251,  0.0066,  0.0187,  ...,  0.0047,  0.0101, -0.0108],
#         [-0.0830, -0.0219, -0.0307,  ..., -0.0312,  0.0072, -0.0218],
#         ...,
#         [ 0.0858,  0.0060, -0.0488,  ...,  0.0604,  0.0463, -0.0154],
#         [-0.0812, -0.0392, -0.0690,  ...,  0.0767, -0.0087, -0.0515],
#         [-0.0036,  0.0253,  0.0316,  ..., -0.0166,  0.0481, -0.0249]])
# encoder.layer.5.intermediate.dense.bias Parameter containing:
# tensor([-0.0559, -0.0603, -0.0565,  ..., -0.0536, -0.0576, -0.0685])
# encoder.layer.5.output.dense.weight Parameter containing:
# tensor([[-0.0285,  0.0434, -0.0244,  ...,  0.0051, -0.0525, -0.0122],
#         [ 0.0201,  0.0696, -0.0003,  ...,  0.0086, -0.0074, -0.0500],
#         [-0.0026, -0.0032,  0.0177,  ...,  0.0193,  0.0044, -0.0195],
#         ...,
#         [ 0.0208, -0.0036, -0.0135,  ...,  0.0117,  0.0226,  0.0176],
#         [-0.0092, -0.0075, -0.0115,  ..., -0.0301, -0.0428,  0.0019],
#         [ 0.0289, -0.0251,  0.0050,  ...,  0.0171, -0.0217,  0.0120]])
# encoder.layer.5.output.dense.bias Parameter containing:
# tensor([ 0.0063,  0.0016, -0.0028,  ...,  0.0771, -0.0376,  0.0196])
# encoder.layer.5.output.LayerNorm.weight Parameter containing:
# tensor([0.8778, 0.8938, 0.8508,  ..., 0.9048, 0.9220, 0.8734])
# encoder.layer.5.output.LayerNorm.bias Parameter containing:
# tensor([ 0.1088, -0.0068, -0.0650,  ...,  0.0521,  0.0519, -0.0059])
# encoder.layer.6.attention.self.query.weight Parameter containing:
# tensor([[ 0.0327,  0.0428, -0.0450,  ..., -0.0749, -0.0086, -0.0152],
#         [ 0.0233, -0.0023,  0.0158,  ..., -0.0134, -0.0489,  0.0517],
#         [ 0.0098, -0.0062, -0.0324,  ...,  0.0356, -0.0829,  0.0182],
#         ...,
#         [ 0.0788,  0.0426, -0.0397,  ...,  0.0409, -0.0337,  0.0497],
#         [ 0.0133,  0.0052, -0.0163,  ..., -0.0279, -0.0208,  0.0040],
#         [ 0.0190,  0.0382,  0.0127,  ...,  0.0090, -0.0045,  0.0096]])
# encoder.layer.6.attention.self.query.bias Parameter containing:
# tensor([ 0.0307, -0.0209, -0.0252,  ..., -0.0358, -0.0292,  0.1060])
# encoder.layer.6.attention.self.key.weight Parameter containing:
# tensor([[ 0.0129,  0.0835,  0.0135,  ..., -0.0549,  0.0710,  0.0189],
#         [ 0.0486, -0.0157, -0.0013,  ...,  0.0665, -0.0484,  0.0509],
#         [-0.0004,  0.0873, -0.0199,  ...,  0.0302, -0.0547,  0.0593],
#         ...,
#         [ 0.0734,  0.0356, -0.0932,  ..., -0.0288, -0.1301,  0.0427],
#         [-0.0016, -0.0409,  0.0231,  ..., -0.0218, -0.0140,  0.0128],
#         [ 0.0133, -0.0032, -0.0503,  ..., -0.0029,  0.0482, -0.0301]])
# encoder.layer.6.attention.self.key.bias Parameter containing:
# tensor([ 0.0059, -0.0055, -0.0027,  ..., -0.0022, -0.0035, -0.0026])
# encoder.layer.6.attention.self.value.weight Parameter containing:
# tensor([[-0.0212, -0.0193, -0.0147,  ..., -0.0069,  0.0303,  0.0315],
#         [-0.0083, -0.0020, -0.0018,  ..., -0.0025, -0.0017, -0.0071],
#         [ 0.0008, -0.0221, -0.0338,  ...,  0.0352, -0.0045, -0.0018],
#         ...,
#         [-0.0234, -0.0430, -0.0120,  ..., -0.0490,  0.0011, -0.0148],
#         [-0.0380,  0.0245, -0.0455,  ...,  0.0081,  0.0124,  0.0549],
#         [ 0.0120, -0.0083,  0.0224,  ..., -0.0128, -0.0061,  0.0146]])
# encoder.layer.6.attention.self.value.bias Parameter containing:
# tensor([-0.0014, -0.0083,  0.0003,  ...,  0.0074, -0.0082, -0.0132])
# encoder.layer.6.attention.output.dense.weight Parameter containing:
# tensor([[ 0.0323, -0.0468, -0.0014,  ...,  0.0136,  0.0125, -0.0282],
#         [-0.0359,  0.0206, -0.0399,  ...,  0.0466,  0.0170,  0.0116],
#         [-0.0044,  0.0024, -0.0693,  ...,  0.0021,  0.0149, -0.0245],
#         ...,
#         [-0.0163, -0.0025, -0.0183,  ...,  0.0198,  0.0138,  0.0176],
#         [ 0.0325,  0.0186, -0.0024,  ..., -0.0192, -0.0088,  0.0092],
#         [-0.0454,  0.0584, -0.0047,  ...,  0.0161, -0.0120, -0.0543]])
# encoder.layer.6.attention.output.dense.bias Parameter containing:
# tensor([-0.0137, -0.0117,  0.0426,  ...,  0.0248, -0.0060,  0.0177])
# encoder.layer.6.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.9451, 0.9476, 0.9945,  ..., 0.9593, 0.9639, 0.9286])
# encoder.layer.6.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0144, -0.0642,  0.2680,  ...,  0.1310, -0.1312,  0.0828])
# encoder.layer.6.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0212, -0.0169,  0.0372,  ...,  0.0432, -0.0228, -0.0374],
#         [ 0.0521,  0.0092, -0.0439,  ...,  0.0267, -0.0718, -0.0419],
#         [-0.0066, -0.0084,  0.0308,  ...,  0.0162, -0.1043, -0.0670],
#         ...,
#         [ 0.0232,  0.0059, -0.0237,  ..., -0.0050, -0.0309,  0.0133],
#         [ 0.0479,  0.0032, -0.0361,  ...,  0.0248,  0.0165,  0.0130],
#         [ 0.0877,  0.0374,  0.0280,  ...,  0.0483, -0.0150, -0.0216]])
# encoder.layer.6.intermediate.dense.bias Parameter containing:
# tensor([-0.0479, -0.0817, -0.0709,  ...,  0.0318, -0.0599, -0.0745])
# encoder.layer.6.output.dense.weight Parameter containing:
# tensor([[ 0.0309,  0.0189, -0.0134,  ...,  0.0148, -0.0722,  0.0515],
#         [-0.0274, -0.0556, -0.0055,  ...,  0.0347,  0.0030,  0.0271],
#         [-0.0396,  0.0031, -0.0374,  ...,  0.0338,  0.0651,  0.0299],
#         ...,
#         [ 0.0393, -0.0033, -0.0024,  ...,  0.0384, -0.0318,  0.0215],
#         [ 0.0041, -0.0230,  0.0443,  ...,  0.0048, -0.0155,  0.0205],
#         [-0.0099,  0.0077, -0.0013,  ...,  0.0282, -0.0027,  0.0180]])
# encoder.layer.6.output.dense.bias Parameter containing:
# tensor([ 0.0135,  0.0333, -0.0458,  ...,  0.0396, -0.0341,  0.0031])
# encoder.layer.6.output.LayerNorm.weight Parameter containing:
# tensor([0.8744, 0.8771, 0.8461,  ..., 0.8877, 0.8948, 0.8590])
# encoder.layer.6.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0482,  0.0233, -0.0764,  ...,  0.0029,  0.0771, -0.0054])
# encoder.layer.7.attention.self.query.weight Parameter containing:
# tensor([[-0.0310, -0.0051,  0.0160,  ..., -0.0097, -0.0123,  0.0030],
#         [-0.0285,  0.0226,  0.0027,  ..., -0.0361,  0.0462, -0.0554],
#         [ 0.0164, -0.0038,  0.0302,  ...,  0.0111,  0.0213, -0.0114],
#         ...,
#         [ 0.0133, -0.0024,  0.0017,  ...,  0.0355,  0.0050,  0.0708],
#         [-0.0070,  0.0270,  0.0048,  ..., -0.0140, -0.0463, -0.0751],
#         [ 0.0369,  0.0275, -0.0102,  ..., -0.0124,  0.0271,  0.0168]])
# encoder.layer.7.attention.self.query.bias Parameter containing:
# tensor([-0.1106,  0.0538, -0.0676,  ...,  0.0677,  0.0745,  0.0282])
# encoder.layer.7.attention.self.key.weight Parameter containing:
# tensor([[ 3.7770e-02,  7.8896e-03,  1.0102e-02,  ...,  9.4997e-03,
#           6.5811e-02,  3.2593e-02],
#         [-5.8926e-02,  5.2928e-02,  5.3857e-03,  ..., -4.2257e-03,
#           4.2505e-02,  5.9289e-02],
#         [ 8.7261e-02, -2.2979e-02,  1.7355e-02,  ...,  1.9022e-02,
#           4.6322e-02, -1.3533e-05],
#         ...,
#         [-7.3140e-04, -4.5663e-02,  8.4963e-03,  ...,  1.7330e-02,
#          -4.6019e-02, -7.8726e-03],
#         [-3.1607e-02,  6.2398e-02, -1.4606e-04,  ...,  2.1339e-03,
#          -2.8158e-02,  4.2171e-02],
#         [ 4.5119e-02,  6.5648e-04,  1.7110e-02,  ...,  1.0086e-02,
#          -9.2409e-03, -1.6384e-02]])
# encoder.layer.7.attention.self.key.bias Parameter containing:
# tensor([ 0.0014,  0.0015, -0.0006,  ..., -0.0027, -0.0006,  0.0005])
# encoder.layer.7.attention.self.value.weight Parameter containing:
# tensor([[ 0.0054, -0.0212,  0.0070,  ..., -0.0419, -0.0233,  0.0108],
#         [-0.0001, -0.0169,  0.0337,  ...,  0.0037, -0.0402, -0.0074],
#         [-0.0433, -0.0084,  0.0247,  ..., -0.0092, -0.0517, -0.0132],
#         ...,
#         [ 0.0128,  0.0079,  0.0321,  ..., -0.0100,  0.0057,  0.0480],
#         [-0.0337, -0.0146,  0.0048,  ...,  0.0314, -0.0113, -0.0005],
#         [-0.0596, -0.0312,  0.0308,  ...,  0.0067,  0.0258, -0.0601]])
# encoder.layer.7.attention.self.value.bias Parameter containing:
# tensor([ 0.0250, -0.0129,  0.0113,  ...,  0.0116, -0.0047,  0.0090])
# encoder.layer.7.attention.output.dense.weight Parameter containing:
# tensor([[ 0.0387,  0.0246,  0.0454,  ..., -0.0088, -0.0026,  0.0588],
#         [-0.0452, -0.0308, -0.0392,  ...,  0.0111,  0.0274,  0.0551],
#         [-0.0043, -0.0030,  0.0059,  ..., -0.0173,  0.0023, -0.0158],
#         ...,
#         [ 0.0006, -0.0082, -0.0202,  ..., -0.0483, -0.0163, -0.0055],
#         [-0.0066,  0.0218, -0.0096,  ..., -0.0089, -0.0097,  0.0101],
#         [-0.0209,  0.0293,  0.0121,  ...,  0.0028,  0.0376,  0.0142]])
# encoder.layer.7.attention.output.dense.bias Parameter containing:
# tensor([ 0.0008,  0.0018,  0.0349,  ...,  0.0149, -0.0073,  0.0137])
# encoder.layer.7.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.9376, 0.9713, 1.0231,  ..., 0.9826, 0.9883, 0.9513])
# encoder.layer.7.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0128, -0.1441,  0.2572,  ...,  0.1779, -0.1139,  0.0834])
# encoder.layer.7.intermediate.dense.weight Parameter containing:
# tensor([[-0.0283, -0.0013, -0.0826,  ..., -0.0511,  0.0345, -0.0613],
#         [ 0.0686,  0.0112, -0.0418,  ..., -0.0731,  0.0032, -0.0287],
#         [ 0.0436,  0.0107,  0.0467,  ..., -0.0426, -0.0266, -0.0113],
#         ...,
#         [ 0.0267, -0.0166,  0.0002,  ..., -0.0260,  0.0364, -0.0126],
#         [-0.0315, -0.0283, -0.0365,  ...,  0.0318, -0.0083,  0.0556],
#         [-0.0141, -0.0290, -0.0328,  ..., -0.0038,  0.0434, -0.0519]])
# encoder.layer.7.intermediate.dense.bias Parameter containing:
# tensor([-0.0705, -0.0617, -0.0680,  ..., -0.0651, -0.0739, -0.0716])
# encoder.layer.7.output.dense.weight Parameter containing:
# tensor([[-0.0191, -0.0007,  0.0728,  ...,  0.0490, -0.0489, -0.0187],
#         [ 0.0117, -0.0379,  0.0282,  ...,  0.0282, -0.0496, -0.0650],
#         [-0.0525,  0.0648, -0.0036,  ...,  0.0718, -0.0017,  0.0341],
#         ...,
#         [-0.0321, -0.0121,  0.0190,  ...,  0.0179, -0.0113, -0.0145],
#         [-0.0059, -0.0174, -0.0123,  ...,  0.0479, -0.0167,  0.0627],
#         [-0.0061, -0.0025, -0.0357,  ..., -0.0194,  0.0339,  0.0290]])
# encoder.layer.7.output.dense.bias Parameter containing:
# tensor([ 0.0151,  0.0405, -0.0587,  ...,  0.0366,  0.0051,  0.0213])
# encoder.layer.7.output.LayerNorm.weight Parameter containing:
# tensor([0.8929, 0.8861, 0.8585,  ..., 0.8940, 0.9277, 0.8695])
# encoder.layer.7.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0182,  0.0538, -0.1402,  ..., -0.0719,  0.0840, -0.0607])
# encoder.layer.8.attention.self.query.weight Parameter containing:
# tensor([[-0.0232,  0.0977, -0.0923,  ..., -0.0231, -0.0518,  0.0158],
#         [ 0.0193, -0.0182, -0.0159,  ...,  0.0264, -0.0404,  0.0324],
#         [ 0.0320,  0.0058, -0.0543,  ..., -0.0479,  0.0027,  0.0390],
#         ...,
#         [-0.0081, -0.0060, -0.0115,  ...,  0.0169, -0.0121,  0.0137],
#         [-0.0072, -0.0287,  0.0201,  ..., -0.0286,  0.0421, -0.0040],
#         [-0.0347, -0.0045,  0.0089,  ...,  0.0077,  0.0175, -0.0224]])
# encoder.layer.8.attention.self.query.bias Parameter containing:
# tensor([ 0.1091,  0.0100,  0.3772,  ..., -0.0221,  0.0223, -0.0586])
# encoder.layer.8.attention.self.key.weight Parameter containing:
# tensor([[ 0.0412, -0.0049, -0.0063,  ..., -0.0287, -0.0257,  0.0084],
#         [ 0.0092,  0.0346,  0.0095,  ...,  0.0137,  0.0353, -0.0168],
#         [-0.0241, -0.0070,  0.0162,  ...,  0.0276, -0.0562,  0.0075],
#         ...,
#         [ 0.0527,  0.0289, -0.0316,  ..., -0.0269, -0.0193, -0.0293],
#         [ 0.0084, -0.0256,  0.0362,  ...,  0.0569,  0.0512, -0.0160],
#         [-0.0223,  0.0117,  0.0510,  ..., -0.0416,  0.0145, -0.0176]])
# encoder.layer.8.attention.self.key.bias Parameter containing:
# tensor([ 4.4108e-04, -9.1703e-05, -6.6812e-03,  ..., -2.2014e-04,
#          2.0029e-03, -7.0794e-04])
# encoder.layer.8.attention.self.value.weight Parameter containing:
# tensor([[-0.0002, -0.0967, -0.0116,  ..., -0.0121, -0.0324,  0.0275],
#         [-0.0098,  0.0113, -0.0253,  ...,  0.0225,  0.0014,  0.0309],
#         [ 0.0024,  0.0226, -0.0267,  ..., -0.0622, -0.0120,  0.0309],
#         ...,
#         [ 0.0231,  0.0277, -0.0249,  ..., -0.0090, -0.0267,  0.0175],
#         [-0.0288, -0.0733,  0.0248,  ..., -0.0058,  0.0364, -0.0173],
#         [-0.0540, -0.0009,  0.0034,  ..., -0.0081, -0.0078,  0.0048]])
# encoder.layer.8.attention.self.value.bias Parameter containing:
# tensor([-0.0073,  0.0110, -0.0173,  ...,  0.0033,  0.0163, -0.0009])
# encoder.layer.8.attention.output.dense.weight Parameter containing:
# tensor([[ 0.0352,  0.0059,  0.0142,  ..., -0.0155,  0.0206,  0.0516],
#         [ 0.0269, -0.0124, -0.0538,  ..., -0.0191,  0.0531,  0.0158],
#         [ 0.0309,  0.0582,  0.0102,  ..., -0.0031, -0.0311,  0.0051],
#         ...,
#         [-0.0433,  0.0169,  0.0259,  ...,  0.0032, -0.0188,  0.0459],
#         [ 0.0315, -0.0366,  0.0125,  ...,  0.0326, -0.0210, -0.0242],
#         [ 0.0205, -0.0334, -0.0326,  ...,  0.0184, -0.0074,  0.0097]])
# encoder.layer.8.attention.output.dense.bias Parameter containing:
# tensor([ 0.0213,  0.0111, -0.0015,  ..., -0.0107, -0.0102, -0.0075])
# encoder.layer.8.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.9414, 0.9569, 0.9890,  ..., 0.9671, 0.9880, 0.9333])
# encoder.layer.8.attention.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0623, -0.0752,  0.2329,  ...,  0.1478, -0.0572,  0.0413])
# encoder.layer.8.intermediate.dense.weight Parameter containing:
# tensor([[-0.0046,  0.0224,  0.0335,  ...,  0.0071,  0.0039, -0.0265],
#         [-0.0116,  0.0148,  0.0460,  ..., -0.0584, -0.0427, -0.0038],
#         [ 0.0308, -0.0002,  0.0260,  ..., -0.0043,  0.0083, -0.0637],
#         ...,
#         [-0.0876,  0.0263,  0.0059,  ...,  0.0397, -0.0074, -0.0322],
#         [-0.0212,  0.0009, -0.0089,  ...,  0.0196,  0.0259, -0.0083],
#         [ 0.0119,  0.0419, -0.0199,  ..., -0.0627,  0.0968, -0.0577]])
# encoder.layer.8.intermediate.dense.bias Parameter containing:
# tensor([-0.0595, -0.0678, -0.0633,  ..., -0.0648, -0.0565, -0.0612])
# encoder.layer.8.output.dense.weight Parameter containing:
# tensor([[ 0.0057, -0.0072, -0.0052,  ...,  0.0012, -0.0240,  0.0434],
#         [-0.0112,  0.0116,  0.0157,  ...,  0.0172, -0.0048,  0.0245],
#         [ 0.0186, -0.0193,  0.0318,  ..., -0.0074, -0.0039, -0.0128],
#         ...,
#         [-0.0486,  0.0288, -0.0630,  ...,  0.0865, -0.0123, -0.0209],
#         [ 0.0482,  0.0033, -0.0258,  ..., -0.0153,  0.0112,  0.0127],
#         [-0.0294, -0.0116, -0.0322,  ...,  0.0101, -0.1396,  0.0351]])
# encoder.layer.8.output.dense.bias Parameter containing:
# tensor([ 0.0061,  0.0209, -0.0293,  ...,  0.0120, -0.0068,  0.0177])
# encoder.layer.8.output.LayerNorm.weight Parameter containing:
# tensor([0.9290, 0.9373, 0.9069,  ..., 0.9473, 0.9934, 0.9036])
# encoder.layer.8.output.LayerNorm.bias Parameter containing:
# tensor([-0.0589,  0.0077, -0.1530,  ..., -0.1121,  0.0355, -0.0659])
# encoder.layer.9.attention.self.query.weight Parameter containing:
# tensor([[ 0.0486,  0.0524,  0.0107,  ..., -0.0196, -0.0245,  0.0057],
#         [ 0.0155, -0.0113, -0.0085,  ...,  0.0677, -0.0767,  0.0140],
#         [ 0.0567,  0.1233,  0.0081,  ..., -0.0681, -0.0477, -0.0055],
#         ...,
#         [ 0.0327,  0.0333, -0.0173,  ...,  0.0771, -0.0206, -0.0186],
#         [-0.0339,  0.0026,  0.0288,  ..., -0.0676,  0.0025,  0.0375],
#         [ 0.0340, -0.0550,  0.0568,  ..., -0.0209, -0.0040,  0.0061]])
# encoder.layer.9.attention.self.query.bias Parameter containing:
# tensor([-0.0313,  0.0450,  0.0471,  ..., -0.1672,  0.1561, -0.3205])
# encoder.layer.9.attention.self.key.weight Parameter containing:
# tensor([[ 3.6360e-02, -2.5708e-02,  1.6931e-02,  ..., -1.0053e-02,
#           8.9737e-03, -3.3915e-02],
#         [ 9.9450e-03, -4.3323e-02,  2.5615e-03,  ...,  1.8223e-02,
#          -4.9840e-02,  2.1404e-02],
#         [-4.8856e-02,  5.5082e-02, -5.5244e-02,  ...,  5.0998e-05,
#          -4.1442e-02,  1.0893e-02],
#         ...,
#         [-6.3390e-03, -8.4831e-02,  3.4318e-04,  ...,  1.8429e-02,
#           3.3636e-02, -1.6249e-02],
#         [-1.6190e-02,  1.4430e-02, -1.0519e-02,  ..., -1.1226e-02,
#          -3.7575e-02, -1.9620e-03],
#         [ 1.1188e-02,  6.3196e-03, -2.1819e-02,  ..., -6.5015e-03,
#           4.6999e-03,  8.6173e-03]])
# encoder.layer.9.attention.self.key.bias Parameter containing:
# tensor([ 4.5914e-03, -2.7998e-03, -8.8724e-03,  ...,  1.5268e-04,
#         -1.9326e-05,  8.1172e-04])
# encoder.layer.9.attention.self.value.weight Parameter containing:
# tensor([[-4.1022e-02, -4.3006e-02, -8.8818e-05,  ..., -4.3832e-03,
#          -2.9209e-02, -1.1038e-02],
#         [-2.9856e-02, -1.5393e-02,  2.7208e-02,  ..., -2.0063e-03,
#           4.5717e-03,  2.5801e-02],
#         [ 2.1817e-02, -5.2769e-03,  1.3679e-02,  ...,  5.2868e-02,
#           1.2223e-02, -3.5320e-02],
#         ...,
#         [-8.7628e-03,  8.5406e-03, -2.1403e-02,  ..., -1.2688e-02,
#           3.6071e-02,  1.8519e-02],
#         [-1.0762e-02, -2.5196e-02,  1.5549e-02,  ..., -1.1992e-02,
#          -1.8076e-02,  1.0748e-02],
#         [-2.4324e-02, -7.1958e-03,  6.1110e-03,  ...,  3.4228e-02,
#          -3.2521e-03, -1.2226e-02]])
# encoder.layer.9.attention.self.value.bias Parameter containing:
# tensor([ 0.0396,  0.0203, -0.0422,  ..., -0.0288,  0.0182, -0.0275])
# encoder.layer.9.attention.output.dense.weight Parameter containing:
# tensor([[-0.0031,  0.0197, -0.0225,  ...,  0.0162,  0.0158,  0.0168],
#         [ 0.0274,  0.0107, -0.0046,  ..., -0.0025,  0.0069, -0.0234],
#         [-0.0240, -0.0532, -0.0513,  ...,  0.0455, -0.0345, -0.0200],
#         ...,
#         [-0.0124, -0.0157, -0.0270,  ..., -0.0111, -0.0237, -0.0198],
#         [ 0.0230, -0.0192, -0.0002,  ..., -0.0008, -0.0157,  0.0051],
#         [-0.0091, -0.0142, -0.0038,  ..., -0.0063,  0.0176, -0.0276]])
# encoder.layer.9.attention.output.dense.bias Parameter containing:
# tensor([-0.0053,  0.0587, -0.0145,  ...,  0.0694, -0.0394,  0.0124])
# encoder.layer.9.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.9398, 0.9498, 0.9914,  ..., 0.9652, 0.9799, 0.9420])
# encoder.layer.9.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0300, -0.0891,  0.2048,  ...,  0.1037,  0.0023, -0.0205])
# encoder.layer.9.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0731,  0.0519, -0.0278,  ...,  0.0483,  0.0514, -0.0432],
#         [-0.0072, -0.0223, -0.0080,  ..., -0.0174,  0.0042, -0.0312],
#         [ 0.0062,  0.0092, -0.0216,  ..., -0.0125,  0.0210, -0.0060],
#         ...,
#         [ 0.0337,  0.0102, -0.0645,  ..., -0.0222,  0.0504, -0.0383],
#         [-0.0076,  0.0240, -0.0171,  ..., -0.0207, -0.0317, -0.0039],
#         [-0.0315, -0.0364, -0.0412,  ..., -0.0789,  0.0058, -0.0404]])
# encoder.layer.9.intermediate.dense.bias Parameter containing:
# tensor([-0.0541, -0.0199, -0.0543,  ..., -0.0739, -0.0204, -0.0644])
# encoder.layer.9.output.dense.weight Parameter containing:
# tensor([[ 0.0440, -0.0008, -0.0383,  ...,  0.0231, -0.0591,  0.0577],
#         [ 0.0365,  0.0186,  0.0189,  ..., -0.0178, -0.0315,  0.0518],
#         [ 0.0557,  0.0020, -0.0303,  ..., -0.0050, -0.0039, -0.0496],
#         ...,
#         [-0.0013, -0.0078, -0.0156,  ...,  0.0419,  0.0341,  0.0036],
#         [ 0.0107,  0.0123, -0.0268,  ..., -0.0030,  0.0091, -0.0035],
#         [ 0.0633, -0.0238, -0.0075,  ..., -0.0247, -0.0227,  0.0159]])
# encoder.layer.9.output.dense.bias Parameter containing:
# tensor([ 0.0060,  0.0037, -0.0194,  ..., -0.0056, -0.0170,  0.0520])
# encoder.layer.9.output.LayerNorm.weight Parameter containing:
# tensor([0.9444, 0.9373, 0.8914,  ..., 0.9418, 1.0049, 0.8925])
# encoder.layer.9.output.LayerNorm.bias Parameter containing:
# tensor([-0.0018,  0.0322, -0.1384,  ..., -0.0846,  0.0262, -0.0524])
# encoder.layer.10.attention.self.query.weight Parameter containing:
# tensor([[-0.0483,  0.0053,  0.0204,  ...,  0.0096,  0.0124,  0.0460],
#         [ 0.0017,  0.0090,  0.0180,  ..., -0.0151,  0.0168, -0.0048],
#         [ 0.0357, -0.0217, -0.0325,  ...,  0.0063,  0.0478,  0.0023],
#         ...,
#         [-0.0259,  0.0137,  0.0110,  ...,  0.0152, -0.0024,  0.0344],
#         [-0.0238,  0.0024,  0.0107,  ..., -0.0379,  0.0071,  0.0380],
#         [-0.0690,  0.0388, -0.0150,  ...,  0.0294,  0.0430, -0.0267]])
# encoder.layer.10.attention.self.query.bias Parameter containing:
# tensor([ 0.0026,  0.0189,  0.0174,  ..., -0.0010, -0.0424, -0.0509])
# encoder.layer.10.attention.self.key.weight Parameter containing:
# tensor([[-0.0080,  0.0021, -0.0151,  ...,  0.0248,  0.0113,  0.0950],
#         [-0.0205, -0.0021,  0.0282,  ...,  0.0589,  0.0135, -0.0124],
#         [ 0.0094,  0.0004, -0.0285,  ...,  0.0028,  0.0318, -0.0218],
#         ...,
#         [-0.0114, -0.0058,  0.0201,  ...,  0.0131, -0.0027, -0.0267],
#         [ 0.0044, -0.0160,  0.0501,  ...,  0.0395,  0.0741,  0.0014],
#         [-0.0325, -0.0214, -0.0826,  ..., -0.0125,  0.0271,  0.0063]])
# encoder.layer.10.attention.self.key.bias Parameter containing:
# tensor([ 0.0023, -0.0015, -0.0017,  ...,  0.0004, -0.0048, -0.0026])
# encoder.layer.10.attention.self.value.weight Parameter containing:
# tensor([[-0.0110,  0.0153,  0.0176,  ..., -0.0032,  0.0381, -0.0028],
#         [ 0.0217, -0.0208,  0.0209,  ..., -0.0029,  0.0028,  0.0064],
#         [-0.0027, -0.0031, -0.0303,  ..., -0.0062,  0.0260,  0.0551],
#         ...,
#         [-0.0068,  0.0618, -0.0514,  ..., -0.0232, -0.0080,  0.0326],
#         [ 0.0267,  0.0477,  0.0226,  ...,  0.0335, -0.0021,  0.0206],
#         [-0.0085,  0.0428,  0.0162,  ..., -0.0422,  0.0011,  0.0356]])
# encoder.layer.10.attention.self.value.bias Parameter containing:
# tensor([-0.0062, -0.0075,  0.0268,  ...,  0.0117, -0.0007, -0.0139])
# encoder.layer.10.attention.output.dense.weight Parameter containing:
# tensor([[-7.1610e-05, -2.6952e-02, -1.1308e-02,  ..., -1.6916e-02,
#           2.2094e-02, -5.2568e-03],
#         [ 6.6971e-04, -6.1078e-03, -5.9845e-02,  ...,  2.2110e-02,
#          -1.9052e-03, -5.9756e-02],
#         [-1.3363e-02, -2.5516e-03,  3.4710e-02,  ...,  3.2721e-02,
#          -2.1918e-02,  2.3161e-03],
#         ...,
#         [ 9.7666e-03, -3.2878e-02, -7.9301e-03,  ...,  1.0020e-02,
#           2.2597e-02, -6.1109e-02],
#         [ 2.2425e-02,  1.8477e-02, -6.7633e-03,  ..., -2.2618e-02,
#           2.2631e-03,  1.6314e-02],
#         [ 3.0337e-02,  3.2732e-03,  3.8291e-02,  ...,  4.9144e-02,
#           3.6681e-02,  1.1555e-02]])
# encoder.layer.10.attention.output.dense.bias Parameter containing:
# tensor([ 0.0155, -0.0060,  0.0176,  ..., -0.0301, -0.0109,  0.0714])
# encoder.layer.10.attention.output.LayerNorm.weight Parameter containing:
# ...
# encoder.layer.20.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0538, -0.0948,  0.0016,  ...,  0.0249,  0.0003,  0.0485])
# encoder.layer.20.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0185,  0.0018, -0.0264,  ...,  0.0706,  0.0091, -0.0265],
#         [-0.0112,  0.0389, -0.0225,  ...,  0.0028, -0.0519, -0.0154],
#         [ 0.0010,  0.0192,  0.0450,  ..., -0.0308, -0.0107, -0.0177],
#         ...,
#         [-0.0146, -0.0040, -0.0403,  ...,  0.0185,  0.0098, -0.0240],
#         [ 0.0178, -0.0106,  0.0130,  ...,  0.0503,  0.0356,  0.0019],
#         [ 0.0112,  0.0263,  0.0028,  ...,  0.0233, -0.0215,  0.0128]])
# encoder.layer.20.intermediate.dense.bias Parameter containing:
# tensor([-0.0243, -0.0642, -0.0596,  ..., -0.0753, -0.0715, -0.0731])
# encoder.layer.20.output.dense.weight Parameter containing:
# tensor([[-0.0552, -0.0093,  0.0167,  ...,  0.0294,  0.0456,  0.0748],
#         [ 0.0166,  0.0041, -0.0345,  ..., -0.0020,  0.0115, -0.0245],
#         [ 0.0126, -0.0634,  0.0330,  ..., -0.0405,  0.0504, -0.0055],
#         ...,
#         [ 0.0031,  0.0016, -0.0088,  ..., -0.0357,  0.0225, -0.0397],
#         [ 0.0026, -0.0020, -0.0026,  ...,  0.0189,  0.0072,  0.0214],
#         [ 0.0117, -0.0163,  0.0014,  ...,  0.0411, -0.0228,  0.0306]])
# encoder.layer.20.output.dense.bias Parameter containing:
# tensor([-0.0354, -0.0540, -0.0133,  ...,  0.0342, -0.0061,  0.0505])
# encoder.layer.20.output.LayerNorm.weight Parameter containing:
# tensor([0.8713, 0.8788, 0.8821,  ..., 0.8960, 0.8872, 0.8679])
# encoder.layer.20.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0182,  0.0217,  0.0041,  ..., -0.0154,  0.0142,  0.0058])
# encoder.layer.21.attention.self.query.weight Parameter containing:
# tensor([[-0.0062,  0.0222, -0.0853,  ...,  0.0289,  0.0476,  0.0530],
#         [-0.0028, -0.0443, -0.0108,  ...,  0.0425, -0.0467,  0.0313],
#         [-0.0004, -0.0193, -0.0765,  ...,  0.0235, -0.0105,  0.0343],
#         ...,
#         [-0.0695,  0.0018,  0.0297,  ..., -0.0425, -0.0359, -0.0183],
#         [-0.0344,  0.0354,  0.0445,  ...,  0.0639, -0.0599, -0.0237],
#         [ 0.0559,  0.0086, -0.0125,  ..., -0.0230, -0.0240,  0.0111]])
# encoder.layer.21.attention.self.query.bias Parameter containing:
# tensor([ 9.3205e-02,  1.1141e-01, -1.9864e-02,  ...,  1.0445e-04,
#          9.0266e-02, -1.5502e-01])
# encoder.layer.21.attention.self.key.weight Parameter containing:
# tensor([[-0.0418,  0.0454,  0.0334,  ..., -0.0185, -0.0205, -0.0361],
#         [ 0.0462, -0.0361,  0.0148,  ...,  0.0139, -0.0874, -0.0046],
#         [-0.0353, -0.0477, -0.0350,  ..., -0.0225,  0.0039,  0.0552],
#         ...,
#         [-0.0463, -0.0145,  0.0349,  ...,  0.0447,  0.0019,  0.0017],
#         [-0.0187,  0.0595,  0.0189,  ...,  0.0251,  0.0214, -0.0444],
#         [-0.0164, -0.0592, -0.0316,  ..., -0.0571, -0.0037, -0.0437]])
# encoder.layer.21.attention.self.key.bias Parameter containing:
# tensor([ 0.0043,  0.0021, -0.0039,  ..., -0.0025,  0.0019,  0.0004])
# encoder.layer.21.attention.self.value.weight Parameter containing:
# tensor([[-0.0352, -0.0731, -0.0216,  ...,  0.1062,  0.0419,  0.0153],
#         [-0.0101, -0.0069,  0.0463,  ..., -0.0090,  0.0136, -0.0520],
#         [-0.0428, -0.0055, -0.0268,  ...,  0.0165, -0.0015, -0.0232],
#         ...,
#         [ 0.0313, -0.0233, -0.0171,  ...,  0.0163, -0.0010,  0.0229],
#         [-0.0256, -0.0052, -0.0141,  ...,  0.0505, -0.0555, -0.0065],
#         [ 0.0712, -0.0285, -0.0096,  ..., -0.0645, -0.0455, -0.0371]])
# encoder.layer.21.attention.self.value.bias Parameter containing:
# tensor([-0.0114,  0.0211,  0.0134,  ..., -0.0052,  0.0004,  0.0129])
# encoder.layer.21.attention.output.dense.weight Parameter containing:
# tensor([[-0.0077,  0.0121,  0.0188,  ..., -0.0527, -0.0066, -0.0421],
#         [ 0.0317,  0.0004, -0.0324,  ..., -0.0084,  0.0215, -0.0473],
#         [-0.0066, -0.0053,  0.0355,  ...,  0.0100,  0.0119, -0.0239],
#         ...,
#         [ 0.0116,  0.0324, -0.0174,  ..., -0.0097, -0.0500, -0.0035],
#         [-0.0319, -0.0276, -0.0088,  ..., -0.0065,  0.0296, -0.0023],
#         [ 0.0074,  0.0191,  0.0695,  ..., -0.0385, -0.0108,  0.0468]])
# encoder.layer.21.attention.output.dense.bias Parameter containing:
# tensor([-0.0066, -0.0711, -0.0169,  ..., -0.0305,  0.0178,  0.0074])
# encoder.layer.21.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.8314, 0.8126, 0.8176,  ..., 0.7901, 0.8274, 0.8074])
# encoder.layer.21.attention.output.LayerNorm.bias Parameter containing:
# tensor([-4.9163e-02, -3.8619e-02, -1.5965e-02,  ...,  3.2479e-02,
#         -4.4565e-06,  6.6333e-02])
# encoder.layer.21.intermediate.dense.weight Parameter containing:
# tensor([[ 2.1294e-02, -1.4662e-03, -4.1065e-02,  ...,  3.0575e-02,
#           1.5024e-05,  1.1022e-02],
#         [ 1.7756e-02,  3.7049e-02,  2.6278e-02,  ..., -3.9000e-02,
#           1.8214e-02, -1.7173e-02],
#         [-4.5715e-03,  5.4492e-02,  4.5252e-03,  ..., -2.1276e-02,
#           2.3224e-03, -6.4660e-02],
#         ...,
#         [ 6.8326e-02,  6.2117e-02,  8.7491e-03,  ..., -2.6476e-02,
#           1.4462e-02, -2.0708e-02],
#         [-2.9243e-03,  4.7225e-02,  7.1076e-02,  ...,  4.6272e-02,
#          -1.6826e-02,  1.1698e-02],
#         [ 1.1435e-02, -4.7138e-02,  1.3275e-02,  ...,  7.6388e-03,
#           2.8070e-03,  5.9110e-02]])
# encoder.layer.21.intermediate.dense.bias Parameter containing:
# tensor([-0.0746, -0.0845, -0.0803,  ..., -0.0616, -0.0224, -0.0538])
# encoder.layer.21.output.dense.weight Parameter containing:
# tensor([[ 0.0070, -0.0139,  0.0047,  ...,  0.0225, -0.0421,  0.0098],
#         [ 0.0040,  0.0333, -0.0154,  ...,  0.0271,  0.0239, -0.0913],
#         [-0.0307, -0.0179,  0.0180,  ...,  0.0103, -0.0033,  0.0301],
#         ...,
#         [ 0.0387, -0.0255, -0.0076,  ..., -0.0243,  0.0043,  0.0222],
#         [-0.0167,  0.0220, -0.0781,  ..., -0.0080, -0.0158,  0.0004],
#         [ 0.0433, -0.0135,  0.0060,  ..., -0.0166, -0.0096,  0.0243]])
# encoder.layer.21.output.dense.bias Parameter containing:
# tensor([-0.0271, -0.0457, -0.0261,  ...,  0.0573,  0.0206,  0.0371])
# encoder.layer.21.output.LayerNorm.weight Parameter containing:
# tensor([0.9007, 0.9155, 0.9140,  ..., 0.9235, 0.9144, 0.9173])
# encoder.layer.21.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0365,  0.0492,  0.0287,  ..., -0.0132,  0.0218,  0.0144])
# encoder.layer.22.attention.self.query.weight Parameter containing:
# tensor([[-0.0282, -0.0173,  0.0468,  ..., -0.0070, -0.0072, -0.0011],
#         [ 0.0115, -0.0500,  0.0150,  ...,  0.0168, -0.0108,  0.0207],
#         [ 0.0202,  0.0609, -0.0256,  ..., -0.0621,  0.0041, -0.0284],
#         ...,
#         [ 0.0240, -0.0031, -0.0447,  ...,  0.0021, -0.0337,  0.0499],
#         [ 0.0475,  0.0406,  0.0208,  ..., -0.0692, -0.0571,  0.0082],
#         [-0.0780,  0.0522,  0.0106,  ..., -0.0173,  0.0255, -0.0836]])
# encoder.layer.22.attention.self.query.bias Parameter containing:
# tensor([ 0.1501, -0.0991,  0.0510,  ...,  0.0147,  0.1117, -0.1311])
# encoder.layer.22.attention.self.key.weight Parameter containing:
# tensor([[ 0.0122,  0.0233,  0.0054,  ...,  0.0205, -0.0093,  0.0382],
#         [ 0.0489, -0.0082,  0.0188,  ..., -0.0040, -0.0188, -0.0261],
#         [ 0.0138, -0.0469,  0.0245,  ...,  0.0058, -0.0139, -0.0722],
#         ...,
#         [-0.0141, -0.0319, -0.0030,  ...,  0.0096, -0.0040,  0.0165],
#         [-0.0572,  0.1023, -0.0177,  ..., -0.0194, -0.0264,  0.0056],
#         [-0.0414, -0.0101,  0.0180,  ...,  0.0427, -0.0052,  0.0039]])
# encoder.layer.22.attention.self.key.bias Parameter containing:
# tensor([-0.0007, -0.0011,  0.0004,  ...,  0.0041,  0.0037,  0.0022])
# encoder.layer.22.attention.self.value.weight Parameter containing:
# tensor([[ 0.0024, -0.0674, -0.0426,  ..., -0.0331,  0.0480, -0.0319],
#         [-0.0365, -0.0665, -0.0111,  ...,  0.0152, -0.0138,  0.0485],
#         [ 0.0606, -0.0028,  0.0283,  ...,  0.0153,  0.0407, -0.0256],
#         ...,
#         [-0.0223, -0.0380,  0.0223,  ..., -0.0022, -0.0055,  0.0011],
#         [ 0.0063,  0.0175,  0.0184,  ..., -0.0018,  0.0099, -0.0059],
#         [-0.0414, -0.0115, -0.0073,  ..., -0.0264, -0.0221,  0.0370]])
# encoder.layer.22.attention.self.value.bias Parameter containing:
# tensor([-0.0119,  0.0088, -0.0041,  ..., -0.0143, -0.0169, -0.0049])
# encoder.layer.22.attention.output.dense.weight Parameter containing:
# tensor([[ 0.0041,  0.0027,  0.0088,  ..., -0.0337, -0.0332,  0.0278],
#         [ 0.0243, -0.0036, -0.0220,  ...,  0.0024, -0.0021,  0.0015],
#         [ 0.0293, -0.0628, -0.0367,  ..., -0.0028,  0.0151, -0.0048],
#         ...,
#         [ 0.0015,  0.0404, -0.0229,  ..., -0.0219,  0.0022, -0.0042],
#         [-0.0955, -0.0381, -0.0020,  ..., -0.0220,  0.0289, -0.0029],
#         [-0.0575, -0.0001, -0.0261,  ..., -0.0021,  0.0447,  0.0161]])
# encoder.layer.22.attention.output.dense.bias Parameter containing:
# tensor([-0.0019,  0.0094, -0.0132,  ..., -0.0102,  0.0068, -0.0059])
# encoder.layer.22.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.8478, 0.8185, 0.8293,  ..., 0.8070, 0.8412, 0.8095])
# encoder.layer.22.attention.output.LayerNorm.bias Parameter containing:
# tensor([-0.0195, -0.0054,  0.0196,  ...,  0.0725,  0.0300,  0.0910])
# encoder.layer.22.intermediate.dense.weight Parameter containing:
# tensor([[-0.0526, -0.0601, -0.0256,  ...,  0.0006,  0.0257,  0.0194],
#         [-0.0601, -0.0404, -0.0369,  ...,  0.0411, -0.0126, -0.0385],
#         [ 0.0195, -0.0211, -0.0011,  ..., -0.0092,  0.0291, -0.0077],
#         ...,
#         [ 0.0195,  0.0279, -0.0137,  ..., -0.0054,  0.0010,  0.0355],
#         [-0.0156, -0.0058, -0.0318,  ...,  0.0147, -0.0180,  0.0280],
#         [-0.0565, -0.0211,  0.0234,  ..., -0.0381, -0.0043, -0.0101]])
# encoder.layer.22.intermediate.dense.bias Parameter containing:
# tensor([-0.0293, -0.0752, -0.0568,  ..., -0.0625, -0.0641, -0.0486])
# encoder.layer.22.output.dense.weight Parameter containing:
# tensor([[-0.0245, -0.0065, -0.0775,  ..., -0.0272, -0.0039,  0.0418],
#         [-0.0255,  0.0016, -0.0200,  ...,  0.0119,  0.0197,  0.0495],
#         [ 0.0230,  0.0072, -0.0197,  ...,  0.0221, -0.0273, -0.0062],
#         ...,
#         [-0.0018, -0.0323,  0.0260,  ..., -0.0350,  0.0087,  0.0465],
#         [ 0.0126, -0.0542, -0.0474,  ..., -0.0108,  0.0173,  0.0145],
#         [-0.0081,  0.0332, -0.0109,  ..., -0.0323,  0.0194,  0.0384]])
# encoder.layer.22.output.dense.bias Parameter containing:
# tensor([-0.0283, -0.0255, -0.0323,  ...,  0.0533, -0.0031,  0.0142])
# encoder.layer.22.output.LayerNorm.weight Parameter containing:
# tensor([0.9302, 0.9363, 0.9304,  ..., 0.9359, 0.9303, 0.9161])
# encoder.layer.22.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0223,  0.0434,  0.0181,  ...,  0.0011,  0.0065, -0.0151])
# encoder.layer.23.attention.self.query.weight Parameter containing:
# tensor([[ 0.0032,  0.0387,  0.0035,  ...,  0.0411,  0.0041, -0.0036],
#         [ 0.0522,  0.0847,  0.0199,  ..., -0.0391,  0.0068, -0.0533],
#         [-0.0102, -0.0414,  0.0207,  ...,  0.0152,  0.0102,  0.0198],
#         ...,
#         [ 0.0786,  0.0222, -0.0259,  ...,  0.0656,  0.0014,  0.0277],
#         [-0.0409, -0.0250,  0.0571,  ...,  0.0283,  0.0322,  0.0689],
#         [ 0.0138, -0.0111,  0.0144,  ...,  0.0543, -0.0150, -0.0009]],
#        requires_grad=True)
# encoder.layer.23.attention.self.query.bias Parameter containing:
# tensor([-0.0960,  0.0029,  0.0376,  ...,  0.1438, -0.0946, -0.2944],
#        requires_grad=True)
# encoder.layer.23.attention.self.key.weight Parameter containing:
# tensor([[-0.0913, -0.0524, -0.0075,  ...,  0.0654,  0.0551,  0.0159],
#         [ 0.0289,  0.0226, -0.0670,  ...,  0.0181,  0.0113, -0.0522],
#         [ 0.0200, -0.0584,  0.0381,  ..., -0.0070,  0.0331,  0.0332],
#         ...,
#         [-0.0074,  0.0464,  0.0360,  ...,  0.0723,  0.0626,  0.0242],
#         [ 0.0444, -0.0327,  0.0539,  ..., -0.0576,  0.0024, -0.0414],
#         [-0.0408, -0.0829, -0.0173,  ..., -0.0260,  0.0043, -0.0394]],
#        requires_grad=True)
# encoder.layer.23.attention.self.key.bias Parameter containing:
# tensor([ 0.0018, -0.0016, -0.0028,  ..., -0.0009, -0.0010, -0.0032],
#        requires_grad=True)
# encoder.layer.23.attention.self.value.weight Parameter containing:
# tensor([[ 0.0495,  0.0120,  0.0117,  ...,  0.0270,  0.0156, -0.0464],
#         [-0.0140,  0.0047,  0.0324,  ...,  0.0133,  0.0601, -0.0438],
#         [ 0.0120, -0.0263,  0.0323,  ..., -0.0069,  0.0323,  0.0182],
#         ...,
#         [-0.0091,  0.0379,  0.0433,  ..., -0.0341,  0.0374, -0.0422],
#         [ 0.0181, -0.0231, -0.0688,  ..., -0.0468,  0.0138, -0.0530],
#         [-0.0161, -0.0354, -0.0272,  ..., -0.0170,  0.0327,  0.0134]],
#        requires_grad=True)
# encoder.layer.23.attention.self.value.bias Parameter containing:
# tensor([-0.0020,  0.0149,  0.0009,  ...,  0.0098, -0.0002, -0.0055],
#        requires_grad=True)
# encoder.layer.23.attention.output.dense.weight Parameter containing:
# tensor([[ 0.0284,  0.0528,  0.0009,  ...,  0.0186, -0.0131, -0.0004],
#         [ 0.0135,  0.0386,  0.0040,  ..., -0.0567,  0.0690,  0.0250],
#         [-0.0145, -0.0147,  0.0295,  ...,  0.0359,  0.0060, -0.0128],
#         ...,
#         [ 0.0675, -0.0103,  0.0222,  ..., -0.0205,  0.0362,  0.0212],
#         [ 0.0038,  0.0331,  0.0204,  ..., -0.0109,  0.0765, -0.0332],
#         [-0.0442, -0.0364, -0.0189,  ...,  0.0282,  0.0168, -0.0194]],
#        requires_grad=True)
# encoder.layer.23.attention.output.dense.bias Parameter containing:
# tensor([-0.0008,  0.0046,  0.0017,  ...,  0.0082,  0.0013, -0.0125],
#        requires_grad=True)
# encoder.layer.23.attention.output.LayerNorm.weight Parameter containing:
# tensor([0.8541, 0.8285, 0.8417,  ..., 0.8122, 0.8599, 0.8210],
#        requires_grad=True)
# encoder.layer.23.attention.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0152,  0.0184,  0.0294,  ..., -0.0048, -0.0135,  0.0127],
#        requires_grad=True)
# encoder.layer.23.intermediate.dense.weight Parameter containing:
# tensor([[ 0.0143, -0.0020, -0.0096,  ..., -0.0190,  0.0411, -0.0354],
#         [-0.0790,  0.0497,  0.0186,  ..., -0.0406,  0.0197,  0.0786],
#         [-0.0251, -0.0161, -0.0535,  ..., -0.0125,  0.0073,  0.0147],
#         ...,
#         [-0.0103, -0.0388, -0.0029,  ..., -0.0095, -0.0307,  0.0054],
#         [ 0.0045,  0.0457, -0.0304,  ..., -0.0104, -0.0169, -0.0103],
#         [ 0.0562, -0.0010, -0.0154,  ..., -0.0186, -0.0100, -0.0146]],
#        requires_grad=True)
# encoder.layer.23.intermediate.dense.bias Parameter containing:
# tensor([-0.0523, -0.0639, -0.0551,  ..., -0.0675, -0.0807, -0.0293],
#        requires_grad=True)
# encoder.layer.23.output.dense.weight Parameter containing:
# tensor([[-0.0404, -0.0155,  0.0406,  ..., -0.0199,  0.0253, -0.0368],
#         [ 0.0703,  0.0240,  0.0815,  ..., -0.0132, -0.0133,  0.0278],
#         [-0.0427,  0.0081, -0.0329,  ..., -0.0201, -0.0155, -0.0443],
#         ...,
#         [ 0.0109, -0.0115, -0.0308,  ..., -0.0022, -0.0333, -0.0335],
#         [-0.0183,  0.0017, -0.0268,  ...,  0.0156, -0.0166,  0.0125],
#         [ 0.0564, -0.0147, -0.0697,  ...,  0.0514,  0.0064, -0.0197]],
#        requires_grad=True)
# encoder.layer.23.output.dense.bias Parameter containing:
# tensor([ 0.0118, -0.0063, -0.0245,  ..., -0.0057, -0.0266,  0.0056],
#        requires_grad=True)
# encoder.layer.23.output.LayerNorm.weight Parameter containing:
# tensor([0.7078, 0.7500, 0.7275,  ..., 0.7114, 0.7231, 0.6928],
#        requires_grad=True)
# encoder.layer.23.output.LayerNorm.bias Parameter containing:
# tensor([ 0.0547,  0.0670,  0.0421,  ..., -0.0172, -0.0762, -0.0607],
#        requires_grad=True)
# pooler.dense.weight Parameter containing:
# tensor([[-0.0391,  0.0444, -0.0249,  ...,  0.0010,  0.0244,  0.0079],
#         [-0.0225,  0.0373, -0.0350,  ..., -0.0122,  0.0424,  0.0095],
#         [-0.0328, -0.0122, -0.0519,  ..., -0.0761,  0.0065, -0.0129],
#         ...,
#         [-0.0033,  0.0137,  0.0128,  ...,  0.0554, -0.0628, -0.0112],
#         [-0.0333,  0.0165, -0.0234,  ..., -0.0384, -0.0343, -0.0629],
#         [ 0.0137,  0.0049, -0.0149,  ...,  0.0111,  0.0091,  0.0217]],
#        requires_grad=True)
# pooler.dense.bias Parameter containing:
# tensor([-0.0365, -0.0285,  0.0037,  ...,  0.0227,  0.0211, -0.0185],
#        requires_grad=True)
